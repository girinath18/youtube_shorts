# %% [markdown]
# <a href="https://colab.research.google.com/github/girinath18/youtube_shorts/blob/august06/Augstin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytubefix
# Out:
# Requirement already satisfied: pytubefix in /usr/local/lib/python3.10/dist-packages (6.8.1)

# %%
import os
import re
from pytubefix import YouTube
from pytubefix.cli import on_progress
import pandas as pd
import requests
import json
from datetime import datetime
import cv2

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def is_video_playable(file_path):
    """
    Check if the video file is playable using OpenCV.
    """
    try:
        cap = cv2.VideoCapture(file_path)
        if not cap.isOpened():
            return False
        ret, frame = cap.read()
        cap.release()
        return ret
    except Exception as e:
        print(f"Error checking video playability: {e}")
        return False

def download_youtube_shorts(url, output_folder):
    try:
        yt = YouTube(url, on_progress_callback=on_progress)
        streams = yt.streams
        streams.filter(progressive=True)
        stream = streams.get_highest_resolution()
        if stream:
            # Download the video
            video_file = stream.download(output_folder)

            # Extract metadata
            title = clean_text(yt.title)
            description = clean_text(yt.description)
            video_id = yt.video_id

            # Generate file name with timestamp
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            new_filename = f"{video_id}_{timestamp}.mp4"
            new_filepath = os.path.join(output_folder, new_filename)
            os.rename(video_file, new_filepath)

            # Save metadata to a text file
            metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
            with open(metadata_file, "w") as f:
                f.write(f"Title: {title}\n")
                f.write(f"Description: {description}\n")
                f.write(f"Video ID: {video_id}\n")

            print("Video downloaded successfully!")

            return title, description, video_id, new_filename, new_filepath
        else:
            print("No suitable streams found for the video.")
            return None, None, None, None, None
    except Exception as e:
        print(f"Error downloading video from URL {url}: {e}")
        return None, None, None, None, None

def upload_video(file_name, file_path):
    try:
        # Read the binary data from the video file
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        # Headers with your access key
        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'  # Specify content type as binary
        }

        # Make a PUT request to the API endpoint with binary data in the request body
        response = requests.put(url + file_name, headers=headers, data=binary_data)

        # Check if the request was successful (status code 201)
        if response.status_code == 201:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        # Define headers with your access key
        headers = {
            'Content-Type': 'application/json',  # Specify content type as JSON
        }

        # Fetch views count from the YouTube video
        yt = YouTube(f"https://www.youtube.com/watch?v={file_name[:-4]}")
        views_count = yt.views

        # Define the JSON payload
        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,  # Using file_name directly
            "views": views_count  # Include views count in the payload
        }

        # Make a POST request to the API endpoint with binary data in the request body
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    # Read input file into a list of lines
    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        # Split each line by comma to get URL, Category, Subcategory
        parts = line.strip().split(',')
        # Take the first three fields, even if there are more
        if len(parts) < 3:
            print(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)

        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        print(f"Downloading video from URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        # Check if the download was successful
        if title and description and video_id and file_name and file_path:
            # Check if the video is playable
            if is_video_playable(file_path):
                # Call the function to upload the video
                if upload_video(file_name, file_path) and create_post(title, description, category, subcategory, file_name):
                    success_count += 1
                else:
                    failure_count += 1
            else:
                print(f"Video {file_name} is not playable and will not be uploaded.")
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            print(f"Failed to download video from URL: {url}")
            failure_count += 1

    # Convert the extracted data to a DataFrame
    extracted_df = pd.DataFrame(extracted_data)

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    print("Upload report saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Enter the path to the input text file: /content/Kaptivate List 2.txt
# Downloading video from URL: https://youtube.com/shorts/D9lpvUDoXLM?si=VCme4Ujky-WmMBsk
# Video downloaded successfully!
# Video D9lpvUDoXLM_20240806114836.mp4 uploaded successfully!
# Video D9lpvUDoXLM_20240806114836.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/CsnPhKu66Y8?si=tJZzossR0DtBr-Sr
# Video downloaded successfully!
# Video CsnPhKu66Y8_20240806114855.mp4 uploaded successfully!
# Video CsnPhKu66Y8_20240806114855.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/kDh-PZPqQRc?si=pgw_z3uNs_kRfc49
# Video downloaded successfully!
# Video kDh-PZPqQRc_20240806114902.mp4 uploaded successfully!
# Video kDh-PZPqQRc_20240806114902.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/fmnSL7CiZnM?si=XoCKOiVUpyi7QmCi
# Video downloaded successfully!
# Video fmnSL7CiZnM_20240806114904.mp4 uploaded successfully!
# Video fmnSL7CiZnM_20240806114904.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/3wCTDVksjNw?si=0EBCEnw2IwFWbygk
# Video downloaded successfully!
# Video 3wCTDVksjNw_20240806114908.mp4 uploaded successfully!
# Video 3wCTDVksjNw_20240806114908.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/LUUyR0qV-z4?si=LC41aZ0UlDSO7tUj
# Video downloaded successfully!
# Video LUUyR0qV-z4_20240806114910.mp4 uploaded successfully!
# Video LUUyR0qV-z4_20240806114910.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/m2X6Z8CCFFo?si=LjC3jfUFF4yFiVWZ
# Video downloaded successfully!
# Video m2X6Z8CCFFo_20240806114913.mp4 uploaded successfully!
# Video m2X6Z8CCFFo_20240806114913.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# Error downloading video from URL https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR: C9a744zp200 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# Downloading video from URL: https://youtube.com/shorts/vE09jn3bd9I?si=5IgLb_YW0vhQk-di
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/vE09jn3bd9I?si=5IgLb_YW0vhQk-di
# Downloading video from URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# Error downloading video from URL https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD: hsyhqqqtTZ0 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# Downloading video from URL: https://youtube.com/shorts/zL-tzTlTW7w?si=1MjvK08gx8XdCyMl
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/zL-tzTlTW7w?si=1MjvK08gx8XdCyMl
# Downloading video from URL: https://youtube.com/shorts/SK6yi_n-Qgw?si=C5TahI0Ozn2dxJH1
# Video downloaded successfully!
# Video SK6yi_n-Qgw_20240806114916.mp4 uploaded successfully!
# Video SK6yi_n-Qgw_20240806114916.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/btyT2IigbYE?si=rXYANdWHdKMPN6v6
# Video downloaded successfully!
# Video btyT2IigbYE_20240806114918.mp4 uploaded successfully!
# Video btyT2IigbYE_20240806114918.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0rGP0jOxs_I?si=RLvv87Mjsx-QpVTm
# Video downloaded successfully!
# Video 0rGP0jOxs_I_20240806114921.mp4 uploaded successfully!
# Video 0rGP0jOxs_I_20240806114921.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/MFkdc-MxqCw?si=VMPmMwC1Meo7cqQc
# Video downloaded successfully!
# Video MFkdc-MxqCw_20240806114924.mp4 uploaded successfully!
# Video MFkdc-MxqCw_20240806114924.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/zNs7u_jmuVU?si=GWbJ0zf4M07lebGe
# Video downloaded successfully!
# Video zNs7u_jmuVU_20240806114927.mp4 uploaded successfully!
# Video zNs7u_jmuVU_20240806114927.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/fdF1Vd6aU-w?si=SXM7rA_nfKiodCO_
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/fdF1Vd6aU-w?si=SXM7rA_nfKiodCO_
# Downloading video from URL: https://youtube.com/shorts/NRkmjIugIWA?si=LcNSUnSJubDiippn
# Video downloaded successfully!
# Video NRkmjIugIWA_20240806114930.mp4 uploaded successfully!
# Video NRkmjIugIWA_20240806114930.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/kdSr97tOkaY?si=cjj3IO9qMwe9ZzYE
# Video downloaded successfully!
# Video kdSr97tOkaY_20240806114933.mp4 uploaded successfully!
# Video kdSr97tOkaY_20240806114933.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/PqBAXx-wkoI?si=_gLctGlel6_USKrd
# Video downloaded successfully!
# Video PqBAXx-wkoI_20240806114936.mp4 uploaded successfully!
# Video PqBAXx-wkoI_20240806114936.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/f7o-pe0kQt4?si=yhq4i8T9hi2O_rnm
# Video downloaded successfully!
# Video f7o-pe0kQt4_20240806114938.mp4 uploaded successfully!
# Video f7o-pe0kQt4_20240806114938.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Zz4IKbpuT2s?si=1_rdzWwtbVn-Niqg
# Video downloaded successfully!
# Video Zz4IKbpuT2s_20240806114941.mp4 uploaded successfully!
# Video Zz4IKbpuT2s_20240806114941.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/LuxSId5mnpY?si=381_Bj62K08zuZ7M
# Video downloaded successfully!
# Video LuxSId5mnpY_20240806114943.mp4 uploaded successfully!
# Video LuxSId5mnpY_20240806114943.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/S4SuqK6JTrY?si=JXaqLVM2M2WEZsT0
# Video downloaded successfully!
# Video S4SuqK6JTrY_20240806114945.mp4 uploaded successfully!
# Video S4SuqK6JTrY_20240806114945.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/hGqcWUT_IVQ?si=peOCXcLX6IWb8dlu
# Video downloaded successfully!
# Video hGqcWUT_IVQ_20240806114948.mp4 uploaded successfully!
# Video hGqcWUT_IVQ_20240806114948.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/BpgWWznKs5s?si=xEvq6qiFDBoEALxo
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/BpgWWznKs5s?si=xEvq6qiFDBoEALxo
# Downloading video from URL: https://youtube.com/shorts/v_crBqQReAc?si=e44t_1NrLwD8XYRw
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/v_crBqQReAc?si=e44t_1NrLwD8XYRw
# Downloading video from URL: https://youtube.com/shorts/OWdh-hPwf6c?si=hf1dmIZOHTyEx8es
# Video downloaded successfully!
# Video OWdh-hPwf6c_20240806114952.mp4 uploaded successfully!
# Video OWdh-hPwf6c_20240806114952.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/mTXV9jElR4M?si=IwTd8uDx_D6c6dN9
# Video downloaded successfully!
# Video mTXV9jElR4M_20240806114955.mp4 uploaded successfully!
# Video mTXV9jElR4M_20240806114955.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/XygR3Vjdzw4?si=Bh_IXU56PPylf46Z
# Video downloaded successfully!
# Video XygR3Vjdzw4_20240806114958.mp4 uploaded successfully!
# Video XygR3Vjdzw4_20240806114958.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/uTC1CNVbT6Y?si=5BYOdAWaXotyjJfw
# Video downloaded successfully!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5e6ebf78f736> in <cell line: 203>()
#     202
#     203 if __name__ == "__main__":
# --> 204     main()
#
# <ipython-input-2-5e6ebf78f736> in main()
#     170             if is_video_playable(file_path):
#     171                 # Call the function to upload the video
# --> 172                 if upload_video(file_name, file_path) and create_post(title, description, category, subcategory, file_name):
#     173                     success_count += 1
#     174                 else:
#
# <ipython-input-2-5e6ebf78f736> in upload_video(file_name, file_path)
#      83
#      84         # Make a PUT request to the API endpoint with binary data in the request body
# ---> 85         response = requests.put(url + file_name, headers=headers, data=binary_data)
#      86
#      87         # Check if the request was successful (status code 201)
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in put(url, data, **kwargs)
#     128     """
#     129
# --> 130     return request("put", url, data=data, **kwargs)
#     131
#     132
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495         # urllib3.request. It also calls makefile (recv) on the socket.
#     496         try:
# --> 497             conn.request(
#     498                 method,
#     499                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     407                     self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     408                 else:
# --> 409                     self.send(chunk)
#     410
#     411         # Regardless of whether we have a body or not, if we're in
#
# /usr/lib/python3.10/http/client.py in send(self, data)
#     997         sys.audit("http.client.send", self, data)
#     998         try:
# --> 999             self.sock.sendall(data)
#    1000         except TypeError:
#    1001             if isinstance(data, collections.abc.Iterable):
#
# /usr/lib/python3.10/ssl.py in sendall(self, data, flags)
#    1264                 amount = len(byte_view)
#    1265                 while count < amount:
# -> 1266                     v = self.send(byte_view[count:])
#    1267                     count += v
#    1268         else:
#
# /usr/lib/python3.10/ssl.py in send(self, data, flags)
#    1233                     "non-zero flags not allowed in calls to send() on %s" %
#    1234                     self.__class__)
# -> 1235             return self._sslobj.write(data)
#    1236         else:
#    1237             return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 800.9 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import os
import re
from pytube import YouTube
import pandas as pd
import requests
import json
from datetime import datetime

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def download_youtube_shorts(url, output_folder):
    try:
        yt = YouTube(url)
        streams = yt.streams
        streams.filter(progressive=True)
        stream = streams.get_highest_resolution()
        if stream:
            # Download the video
            video_file = stream.download(output_folder)

            # Extract metadata
            title = clean_text(yt.title)
            description = clean_text(yt.description)
            video_id = yt.video_id

            # Generate file name with timestamp
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            new_filename = f"{video_id}_{timestamp}.mp4"
            new_filepath = os.path.join(output_folder, new_filename)
            os.rename(video_file, new_filepath)

            # Save metadata to a text file
            metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
            with open(metadata_file, "w") as f:
                f.write(f"Title: {title}\n")
                f.write(f"Description: {description}\n")
                f.write(f"Video ID: {video_id}\n")

            print("Video downloaded successfully!")

            return title, description, video_id, new_filename, new_filepath
        else:
            print("No suitable streams found for the video.")
            return None, None, None, None, None
    except Exception as e:
        print(f"Error downloading video from URL {url}: {e}")
        return None, None, None, None, None


def upload_video(file_name, file_path):
    try:
        # Read the binary data from the video file
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        # Headers with your access key
        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'  # Specify content type as binary
        }

        # Make a PUT request to the API endpoint with binary data in the request body
        response = requests.put(url + file_name, headers=headers, data=binary_data)

        # Check if the request was successful (status code 200)
        if response.status_code == 201:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        # Define headers with your access key
        headers = {
            'Content-Type': 'application/json',  # Specify content type as JSON
        }

        # Fetch views count from the YouTube video
        yt = YouTube(f"https://www.youtube.com/watch?v={file_name[:-4]}")
        views_count = yt.views

        # Define the JSON payload
        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,  # Using file_name directly
            "views": views_count  # Include views count in the payload
        }

        # Make a POST request to the API endpoint with binary data in the request body
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    # Read input file into a list of lines
    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        # Split each line by comma to get URL, Category, Subcategory
        parts = line.strip().split(',')
        # Take the first three fields, even if there are more
        if len(parts) < 3:
            print(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)

        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        print(f"Downloading video from URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        # Check if the download was successful
        if title and description and video_id and file_name and file_path:
            # Call the function to upload the video
            if upload_video(file_name, file_path) and create_post(title, description, category, subcategory , file_name):
                success_count += 1
            else:
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            print(f"Failed to download video from URL: {url}")
            failure_count += 1

    # Convert the extracted data to a DataFrame
    extracted_df = pd.DataFrame(extracted_data)

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    print("Upload report saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Video downloaded successfully!
# Video ry-VLl5mz1Q_20240417052135.mp4 uploaded successfully!
# Video ry-VLl5mz1Q_20240417052135.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/kB4GsKmyHZY?si=yR4yIZib3qzb0M5e
# Error downloading video from URL https://youtube.com/shorts/kB4GsKmyHZY?si=yR4yIZib3qzb0M5e: kB4GsKmyHZY is unavailable
# Failed to download video from URL: https://youtube.com/shorts/kB4GsKmyHZY?si=yR4yIZib3qzb0M5e
# Downloading video from URL: https://youtube.com/shorts/8IgJLPUZdjU?si=ssSmeblTnp66nxVl
# Error downloading video from URL https://youtube.com/shorts/8IgJLPUZdjU?si=ssSmeblTnp66nxVl: 8IgJLPUZdjU is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/8IgJLPUZdjU?si=ssSmeblTnp66nxVl
# Downloading video from URL: https://youtube.com/shorts/bA4w3C31Wz4?si=xC8y0nSZNWY7JRJg
# Error downloading video from URL https://youtube.com/shorts/bA4w3C31Wz4?si=xC8y0nSZNWY7JRJg: bA4w3C31Wz4 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/bA4w3C31Wz4?si=xC8y0nSZNWY7JRJg
# Downloading video from URL: https://youtube.com/shorts/qwsJnyknoFk?si=JxQdVywYYWLoLRET
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/qwsJnyknoFk?si=JxQdVywYYWLoLRET
# Downloading video from URL: https://youtube.com/shorts/o-CmyXoUUCc?si=LIorqG9UNVESHGBJ
# Error downloading video from URL https://youtube.com/shorts/o-CmyXoUUCc?si=LIorqG9UNVESHGBJ: o-CmyXoUUCc is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/o-CmyXoUUCc?si=LIorqG9UNVESHGBJ
# Downloading video from URL: https://youtube.com/shorts/58ptRTg4_LM?si=k3TRzuOz5EV5Dggk
# Error downloading video from URL https://youtube.com/shorts/58ptRTg4_LM?si=k3TRzuOz5EV5Dggk: 58ptRTg4_LM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/58ptRTg4_LM?si=k3TRzuOz5EV5Dggk
# Downloading video from URL: https://youtube.com/shorts/59aZ7nQ89GM?si=SSX8hMfO80eTvtpQ
# Error downloading video from URL https://youtube.com/shorts/59aZ7nQ89GM?si=SSX8hMfO80eTvtpQ: 59aZ7nQ89GM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/59aZ7nQ89GM?si=SSX8hMfO80eTvtpQ
# Downloading video from URL: https://youtube.com/shorts/myjtJ1YzCiI?si=UeTPIMA0d31j4bwI
# Video downloaded successfully!
# Video myjtJ1YzCiI_20240417052148.mp4 uploaded successfully!
# Video myjtJ1YzCiI_20240417052148.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/5umS0U76jWY?si=Z2K70ihHXNBKgFeg
# Video downloaded successfully!
# Video 5umS0U76jWY_20240417052153.mp4 uploaded successfully!
# Video 5umS0U76jWY_20240417052153.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/rm-G_ZyxTII?si=-3YHjIMbzHP-B9Gn
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/rm-G_ZyxTII?si=-3YHjIMbzHP-B9Gn
# Downloading video from URL: https://youtube.com/shorts/tW1qHpoox-M?si=efQPj7jblj-896zK
# Video downloaded successfully!
# Video tW1qHpoox-M_20240417052205.mp4 uploaded successfully!
# Video tW1qHpoox-M_20240417052205.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/efmPmuwpWDc?si=QcdBEdf2ovvCUX9a
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/efmPmuwpWDc?si=QcdBEdf2ovvCUX9a
# Downloading video from URL: https://youtube.com/shorts/EltPwLGSIM8?si=W9jCV3kJ2tLyI0eB
# Video downloaded successfully!
# Video EltPwLGSIM8_20240417052213.mp4 uploaded successfully!
# Video EltPwLGSIM8_20240417052213.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/bMFSuSl56vA?si=N_va0LSw2u1d7R6t
# Error downloading video from URL https://youtube.com/shorts/bMFSuSl56vA?si=N_va0LSw2u1d7R6t: bMFSuSl56vA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/bMFSuSl56vA?si=N_va0LSw2u1d7R6t
# Downloading video from URL: https://youtube.com/shorts/eOXS7VLq56w?si=oT2bzMzLTs7eAmgf
# Video downloaded successfully!
# Video eOXS7VLq56w_20240417052220.mp4 uploaded successfully!
# Video eOXS7VLq56w_20240417052220.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/KvZJKktLXX4?si=_rkjVPh3jgheVz14
# Video downloaded successfully!
# Video KvZJKktLXX4_20240417052224.mp4 uploaded successfully!
# Video KvZJKktLXX4_20240417052224.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/V4-GxywS58Q?si=SZZ0NkpAavoc0a5R
# Video downloaded successfully!
# Video V4-GxywS58Q_20240417052229.mp4 uploaded successfully!
# Video V4-GxywS58Q_20240417052229.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/1H1m2fsezOw?si=XXP2qJhc5AlmEOIO
# Error downloading video from URL https://youtube.com/shorts/1H1m2fsezOw?si=XXP2qJhc5AlmEOIO: 1H1m2fsezOw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/1H1m2fsezOw?si=XXP2qJhc5AlmEOIO
# Downloading video from URL: https://youtube.com/shorts/SMAyPsM1ROQ?si=Ojq-9Gwje2gWkq24
# Error downloading video from URL https://youtube.com/shorts/SMAyPsM1ROQ?si=Ojq-9Gwje2gWkq24: SMAyPsM1ROQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/SMAyPsM1ROQ?si=Ojq-9Gwje2gWkq24
# Downloading video from URL: https://youtube.com/shorts/_fmgJ0lFgDk?si=WKLxTtERSXtPnEiJ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/_fmgJ0lFgDk?si=WKLxTtERSXtPnEiJ
# Downloading video from URL: https://youtube.com/shorts/PxP9rHOZbZc?si=4GaSDL2P3Ad51E8X
# Error downloading video from URL https://youtube.com/shorts/PxP9rHOZbZc?si=4GaSDL2P3Ad51E8X: PxP9rHOZbZc is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/PxP9rHOZbZc?si=4GaSDL2P3Ad51E8X
# Downloading video from URL: https://youtube.com/shorts/k9kW_1EjQfQ?si=U2TSa4fPPPKovMsN
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/k9kW_1EjQfQ?si=U2TSa4fPPPKovMsN
# Downloading video from URL: https://youtube.com/shorts/kZQRVc2zbVw?si=lfb77JkW7TetlgYU
# Video downloaded successfully!
# Video kZQRVc2zbVw_20240417052250.mp4 uploaded successfully!
# Video kZQRVc2zbVw_20240417052250.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/UYjnEXMZaIo?si=7-HehMukF0K7rWlj
# Error downloading video from URL https://youtube.com/shorts/UYjnEXMZaIo?si=7-HehMukF0K7rWlj: UYjnEXMZaIo is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/UYjnEXMZaIo?si=7-HehMukF0K7rWlj
# Downloading video from URL: https://youtube.com/shorts/JlhlqnLhQ3Q?si=6v0PeQr7r8UG5yzX
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/JlhlqnLhQ3Q?si=6v0PeQr7r8UG5yzX
# Downloading video from URL: https://youtube.com/shorts/H-g_BNHzJz8?si=lEpcscrDIygwVQbo
# Error downloading video from URL https://youtube.com/shorts/H-g_BNHzJz8?si=lEpcscrDIygwVQbo: H-g_BNHzJz8 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/H-g_BNHzJz8?si=lEpcscrDIygwVQbo
# Downloading video from URL: https://youtube.com/shorts/IedqiN5GsZE?si=bgpCtSqn3e0hWYQN
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/IedqiN5GsZE?si=bgpCtSqn3e0hWYQN
# Downloading video from URL: https://youtube.com/shorts/DpwLwxcrMkQ?si=o26vmIODe79Oy5FR
# Video downloaded successfully!
# Video DpwLwxcrMkQ_20240417052304.mp4 uploaded successfully!
# Video DpwLwxcrMkQ_20240417052304.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/7Ta3gNc0a2o?si=nCMiCLXUTTh9K3X_
# Error downloading video from URL https://youtube.com/shorts/7Ta3gNc0a2o?si=nCMiCLXUTTh9K3X_: 7Ta3gNc0a2o is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/7Ta3gNc0a2o?si=nCMiCLXUTTh9K3X_
# Downloading video from URL: https://youtube.com/shorts/l9daO7XvNJ4?si=K3KLFoR2vCc8o2vT
# Video downloaded successfully!
# Video l9daO7XvNJ4_20240417052313.mp4 uploaded successfully!
# Video l9daO7XvNJ4_20240417052313.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/7bX7K5khI1Y?si=AX6bV34snshMXRPA
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/7bX7K5khI1Y?si=AX6bV34snshMXRPA
# Downloading video from URL: https://youtube.com/shorts/v2d3Ncq4bCk?si=WhcLDpc1F-VLCW27
# Error downloading video from URL https://youtube.com/shorts/v2d3Ncq4bCk?si=WhcLDpc1F-VLCW27: v2d3Ncq4bCk is unavailable
# Failed to download video from URL: https://youtube.com/shorts/v2d3Ncq4bCk?si=WhcLDpc1F-VLCW27
# Downloading video from URL: https://youtube.com/shorts/lhkCMphubD0?si=4bPJ_hhw0QciLau2
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/lhkCMphubD0?si=4bPJ_hhw0QciLau2
# Downloading video from URL: https://youtube.com/shorts/m-8y-Knc5NU?si=t0B-8HS9cbTzeswh
# Error downloading video from URL https://youtube.com/shorts/m-8y-Knc5NU?si=t0B-8HS9cbTzeswh: m-8y-Knc5NU is unavailable
# Failed to download video from URL: https://youtube.com/shorts/m-8y-Knc5NU?si=t0B-8HS9cbTzeswh
# Downloading video from URL: https://youtube.com/shorts/W4RmaeDIMrM?si=EvUdtrM2EVOR-fKZ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/W4RmaeDIMrM?si=EvUdtrM2EVOR-fKZ
# Downloading video from URL: https://youtube.com/shorts/5zLkvDC_qAc?si=ZFTiYsIuRaUwHJsT
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/5zLkvDC_qAc?si=ZFTiYsIuRaUwHJsT
# Downloading video from URL: https://youtube.com/shorts/N_2J_FqWdEU?si=1sUjQxoDzWbn8uje
# Video downloaded successfully!
# Video N_2J_FqWdEU_20240417052330.mp4 uploaded successfully!
# Video N_2J_FqWdEU_20240417052330.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/hUBCSNGUNHA?si=6rI5TvRC8a0g-SUg
# Video downloaded successfully!
# Video hUBCSNGUNHA_20240417052334.mp4 uploaded successfully!
# Video hUBCSNGUNHA_20240417052334.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/MKI0M2i95xg?si=wE5mRQTmwVAveW9A
# Error downloading video from URL https://youtube.com/shorts/MKI0M2i95xg?si=wE5mRQTmwVAveW9A: MKI0M2i95xg is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/MKI0M2i95xg?si=wE5mRQTmwVAveW9A
# Downloading video from URL: https://youtube.com/shorts/n3SjZ63XHww?si=LvKSdzZCFbf3b54P
# Error downloading video from URL https://youtube.com/shorts/n3SjZ63XHww?si=LvKSdzZCFbf3b54P: n3SjZ63XHww is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/n3SjZ63XHww?si=LvKSdzZCFbf3b54P
# Downloading video from URL: https://youtube.com/shorts/wmfPSHknxQQ?si=3XPTZEF107K0mYw3
# Error downloading video from URL https://youtube.com/shorts/wmfPSHknxQQ?si=3XPTZEF107K0mYw3: wmfPSHknxQQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/wmfPSHknxQQ?si=3XPTZEF107K0mYw3
# Downloading video from URL: https://youtube.com/shorts/YQis7Imwsjs?si=99qeozTkg_-7Tniw
# Error downloading video from URL https://youtube.com/shorts/YQis7Imwsjs?si=99qeozTkg_-7Tniw: YQis7Imwsjs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/YQis7Imwsjs?si=99qeozTkg_-7Tniw
# Downloading video from URL: https://youtube.com/shorts/uB-XNHUCxxw?si=CiB_xyn3uo-1SDOz
# Video downloaded successfully!
# Video uB-XNHUCxxw_20240417052345.mp4 uploaded successfully!
# Video uB-XNHUCxxw_20240417052345.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/FtRy40l54uc?si=gdhmoRs-hoGoIO8d
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/FtRy40l54uc?si=gdhmoRs-hoGoIO8d
# Downloading video from URL: https://youtube.com/shorts/WaadOW3T5nI?si=iYUaoM_0ID7u0o0W
# Error downloading video from URL https://youtube.com/shorts/WaadOW3T5nI?si=iYUaoM_0ID7u0o0W: WaadOW3T5nI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/WaadOW3T5nI?si=iYUaoM_0ID7u0o0W
# Downloading video from URL: https://youtube.com/shorts/VmlFW2QLeZQ?si=Qt279KRBlUhTBxWb
# Video downloaded successfully!
# Video VmlFW2QLeZQ_20240417052357.mp4 uploaded successfully!
# Video VmlFW2QLeZQ_20240417052357.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/SFI0teag6jY?si=xqdkHB1cVbN5oJNu
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/SFI0teag6jY?si=xqdkHB1cVbN5oJNu
# Downloading video from URL: https://youtube.com/shorts/kY5OGGm0d3A?si=hzsQpe2NqBJ9uWrp
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/kY5OGGm0d3A?si=hzsQpe2NqBJ9uWrp
# Downloading video from URL: https://youtube.com/shorts/ivX8_EZAs9I?si=1I86V5ePOdrWuA9k
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ivX8_EZAs9I?si=1I86V5ePOdrWuA9k
# Downloading video from URL: https://youtube.com/shorts/5XExkS6ODJk?si=2pKSyWWBaQ2wBekx
# Error downloading video from URL https://youtube.com/shorts/5XExkS6ODJk?si=2pKSyWWBaQ2wBekx: 5XExkS6ODJk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/5XExkS6ODJk?si=2pKSyWWBaQ2wBekx
# Downloading video from URL: https://youtube.com/shorts/ISuKN6YsbEY?si=aXbSov80LVuwl9F-
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ISuKN6YsbEY?si=aXbSov80LVuwl9F-
# Downloading video from URL: https://youtube.com/shorts/EQMH0EgQFMs?si=-8aqijB95rAjAesM
# Error downloading video from URL https://youtube.com/shorts/EQMH0EgQFMs?si=-8aqijB95rAjAesM: EQMH0EgQFMs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/EQMH0EgQFMs?si=-8aqijB95rAjAesM
# Downloading video from URL: https://youtube.com/shorts/QhxdWcJw_yM?si=1MuVzMzDKgtnKTSE
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/QhxdWcJw_yM?si=1MuVzMzDKgtnKTSE
# Downloading video from URL: https://youtube.com/shorts/TCfDQOEq7rs?si=jONQiMw1kcgQwKzP
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/TCfDQOEq7rs?si=jONQiMw1kcgQwKzP
# Downloading video from URL: https://youtube.com/shorts/BuDFnawRZos?si=wu8Cr6YkNghOLQZF
# Video downloaded successfully!
# Video BuDFnawRZos_20240417052437.mp4 uploaded successfully!
# Video BuDFnawRZos_20240417052437.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0124Ry5sMkE?si=X0GhnkLCe7YG0DEO
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/0124Ry5sMkE?si=X0GhnkLCe7YG0DEO
# Downloading video from URL: https://youtube.com/shorts/Em7qbmrZ9y0?si=rWj_bbuXSRiGLdd9
# Video downloaded successfully!
# Video Em7qbmrZ9y0_20240417052443.mp4 uploaded successfully!
# Video Em7qbmrZ9y0_20240417052443.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/9FXDGKTkU8c?si=pCJdOx_t8ypRU69L
# Video downloaded successfully!
# Video 9FXDGKTkU8c_20240417052451.mp4 uploaded successfully!
# Video 9FXDGKTkU8c_20240417052451.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ftYIvF8VwcM?si=_8mEyR-oWOkfC4AL
# Video downloaded successfully!
# Video ftYIvF8VwcM_20240417052458.mp4 uploaded successfully!
# Video ftYIvF8VwcM_20240417052458.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/WpMOW9REYfY?si=kssmVMhCmpVKh8Aj
# Video downloaded successfully!
# Video WpMOW9REYfY_20240417052505.mp4 uploaded successfully!
# Video WpMOW9REYfY_20240417052505.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/jlaf_sRQCNg?si=DMa5ZV0FGRTFle3L
# Error downloading video from URL https://youtube.com/shorts/jlaf_sRQCNg?si=DMa5ZV0FGRTFle3L: jlaf_sRQCNg is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/jlaf_sRQCNg?si=DMa5ZV0FGRTFle3L
# Downloading video from URL: https://youtube.com/shorts/9W__RccHPiw?si=hCvMDz7jCq8B1ije
# Video downloaded successfully!
# Video 9W__RccHPiw_20240417052512.mp4 uploaded successfully!
# Video 9W__RccHPiw_20240417052512.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/7eqYYB734ic?si=Fe24kh-VHgVCi-yx
# Video downloaded successfully!
# Video 7eqYYB734ic_20240417052518.mp4 uploaded successfully!
# Video 7eqYYB734ic_20240417052518.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/N1KOTzbQ6xw?si=PGyB0algupkVJwk_
# Error downloading video from URL https://youtube.com/shorts/N1KOTzbQ6xw?si=PGyB0algupkVJwk_: N1KOTzbQ6xw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/N1KOTzbQ6xw?si=PGyB0algupkVJwk_
# Downloading video from URL: https://youtube.com/shorts/vTtUTUDDiRY?si=-yPG8MwM8RSmJ5dW
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/vTtUTUDDiRY?si=-yPG8MwM8RSmJ5dW
# Downloading video from URL: https://youtube.com/shorts/LHU4Lswcdb8?si=9HCV5NDScyymxlnK
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/LHU4Lswcdb8?si=9HCV5NDScyymxlnK
# Downloading video from URL: https://youtube.com/shorts/kA2aeYOGhiw?si=cBPwGhF_n0vIoAoA
# Video downloaded successfully!
# Video kA2aeYOGhiw_20240417052527.mp4 uploaded successfully!
# Video kA2aeYOGhiw_20240417052527.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/XyU1bktO3Ck?si=DX8MO6rPcmQcZgFf
# Error downloading video from URL https://youtube.com/shorts/XyU1bktO3Ck?si=DX8MO6rPcmQcZgFf: XyU1bktO3Ck is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/XyU1bktO3Ck?si=DX8MO6rPcmQcZgFf
# Downloading video from URL: https://youtube.com/shorts/x8Wb_o5kLbw?si=qUFDff_1TEoPUXbQ
# Error downloading video from URL https://youtube.com/shorts/x8Wb_o5kLbw?si=qUFDff_1TEoPUXbQ: x8Wb_o5kLbw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/x8Wb_o5kLbw?si=qUFDff_1TEoPUXbQ
# Downloading video from URL: https://youtube.com/shorts/zbw_1UZ-YR4?si=sea1SS4XI6hNR7i9
# Video downloaded successfully!
# Video zbw_1UZ-YR4_20240417052533.mp4 uploaded successfully!
# Video zbw_1UZ-YR4_20240417052533.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/hjCEMVsGFW8?si=CMQj8B-2-lYfJ0U8
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/hjCEMVsGFW8?si=CMQj8B-2-lYfJ0U8
# Downloading video from URL: https://youtube.com/shorts/SZn69vtvjEg?si=dRVGxojrxMPVouSl
# Video downloaded successfully!
# Video SZn69vtvjEg_20240417052540.mp4 uploaded successfully!
# Video SZn69vtvjEg_20240417052540.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/hcyJGtwaTE4?si=Lg1GJUh5pHW0zLbt
# Video downloaded successfully!
# Video hcyJGtwaTE4_20240417052545.mp4 uploaded successfully!
# Video hcyJGtwaTE4_20240417052545.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/sVCCVz0rDlo?si=9ngYRBpBj1JyCXLj
# Video downloaded successfully!
# Video sVCCVz0rDlo_20240417052549.mp4 uploaded successfully!
# Video sVCCVz0rDlo_20240417052549.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/4IjSgdwbDIQ?si=f0VOmY3vghlS5ZJt
# Error downloading video from URL https://youtube.com/shorts/4IjSgdwbDIQ?si=f0VOmY3vghlS5ZJt: 4IjSgdwbDIQ is unavailable
# Failed to download video from URL: https://youtube.com/shorts/4IjSgdwbDIQ?si=f0VOmY3vghlS5ZJt
# Downloading video from URL: https://youtube.com/shorts/TPaHu_YlVjk?si=MSRiXfnyOhz5q5Hy
# Error downloading video from URL https://youtube.com/shorts/TPaHu_YlVjk?si=MSRiXfnyOhz5q5Hy: TPaHu_YlVjk is unavailable
# Failed to download video from URL: https://youtube.com/shorts/TPaHu_YlVjk?si=MSRiXfnyOhz5q5Hy
# Downloading video from URL: https://youtube.com/shorts/7bmqjsrTT54?si=foEwyTY7vaV1QksA
# Video downloaded successfully!
# Video 7bmqjsrTT54_20240417052555.mp4 uploaded successfully!
# Video 7bmqjsrTT54_20240417052555.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/fja5V8JdXxc?si=k6mauclNUwCgNgBt
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/fja5V8JdXxc?si=k6mauclNUwCgNgBt
# Downloading video from URL: https://youtube.com/shorts/4DouVISX_Es?si=NLlbASio8okUq14l
# Error downloading video from URL https://youtube.com/shorts/4DouVISX_Es?si=NLlbASio8okUq14l: 4DouVISX_Es is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/4DouVISX_Es?si=NLlbASio8okUq14l
# Downloading video from URL: https://youtube.com/shorts/i2tRIthMrDs?si=AkbtIqMB2Gz8rwzT
# Error downloading video from URL https://youtube.com/shorts/i2tRIthMrDs?si=AkbtIqMB2Gz8rwzT: i2tRIthMrDs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/i2tRIthMrDs?si=AkbtIqMB2Gz8rwzT
# Downloading video from URL: https://youtube.com/shorts/hcPvffeFB8I?si=cYueXoZrBJntg1B1
# Error downloading video from URL https://youtube.com/shorts/hcPvffeFB8I?si=cYueXoZrBJntg1B1: hcPvffeFB8I is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/hcPvffeFB8I?si=cYueXoZrBJntg1B1
# Downloading video from URL: https://youtube.com/shorts/LHYfPvp4mxo?si=0kwTr-8YBOiDbHbl
# Video downloaded successfully!
# Video LHYfPvp4mxo_20240417052605.mp4 uploaded successfully!
# Video LHYfPvp4mxo_20240417052605.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/uF-7fup5CGU?si=S0pxC4xmiEFSOxbl
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/uF-7fup5CGU?si=S0pxC4xmiEFSOxbl
# Downloading video from URL: https://youtube.com/shorts/93C8h_yPb1U?si=_CoFA9wnHcA8g14I
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/93C8h_yPb1U?si=_CoFA9wnHcA8g14I
# Downloading video from URL: https://youtube.com/shorts/R11HiBHmpeg?si=lbSgZj8Ot0N9xyD7
# Error downloading video from URL https://youtube.com/shorts/R11HiBHmpeg?si=lbSgZj8Ot0N9xyD7: R11HiBHmpeg is unavailable
# Failed to download video from URL: https://youtube.com/shorts/R11HiBHmpeg?si=lbSgZj8Ot0N9xyD7
# Downloading video from URL: https://youtube.com/shorts/pz99CbxX8MI?si=ENhaVvw2vjoH1fkS
# Error downloading video from URL https://youtube.com/shorts/pz99CbxX8MI?si=ENhaVvw2vjoH1fkS: pz99CbxX8MI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/pz99CbxX8MI?si=ENhaVvw2vjoH1fkS
# Downloading video from URL: https://youtube.com/shorts/Hvxn9qT1Wgs?si=-fhuMtWmoVV8Ed1_
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Hvxn9qT1Wgs?si=-fhuMtWmoVV8Ed1_
# Downloading video from URL: https://youtube.com/shorts/-8hS4lpAK4g?si=xPDqxNvgI1PAoFsY
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/-8hS4lpAK4g?si=xPDqxNvgI1PAoFsY
# Downloading video from URL: https://youtube.com/shorts/gobpBuk-2lk?si=kWcIhXBkth167OLf
# Video downloaded successfully!
# Video gobpBuk-2lk_20240417052630.mp4 uploaded successfully!
# Video gobpBuk-2lk_20240417052630.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/OU6g3MW_R8k?si=DYlodgv7PSp3hGG8
# Video downloaded successfully!
# Video OU6g3MW_R8k_20240417052639.mp4 uploaded successfully!
# Video OU6g3MW_R8k_20240417052639.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/xvqYhG0-tEo?si=TSwU0FgJ6myLcf9e
# Error downloading video from URL https://youtube.com/shorts/xvqYhG0-tEo?si=TSwU0FgJ6myLcf9e: xvqYhG0-tEo is unavailable
# Failed to download video from URL: https://youtube.com/shorts/xvqYhG0-tEo?si=TSwU0FgJ6myLcf9e
# Downloading video from URL: https://youtube.com/shorts/EY18trprNPE?si=oj-pfnl0M1RlYwqv
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/EY18trprNPE?si=oj-pfnl0M1RlYwqv
# Downloading video from URL: https://youtube.com/shorts/8sS7m5XgR9c?si=bNsReJe0qrBDRCBJ
# Error downloading video from URL https://youtube.com/shorts/8sS7m5XgR9c?si=bNsReJe0qrBDRCBJ: 8sS7m5XgR9c is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/8sS7m5XgR9c?si=bNsReJe0qrBDRCBJ
# Downloading video from URL: https://youtube.com/shorts/wfBqD4_WS3U?si=CX74t2r7QJqkwZMC
# Error downloading video from URL https://youtube.com/shorts/wfBqD4_WS3U?si=CX74t2r7QJqkwZMC: wfBqD4_WS3U is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/wfBqD4_WS3U?si=CX74t2r7QJqkwZMC
# Downloading video from URL: https://youtube.com/shorts/jr6K_a9CRYg?si=h9rxdXWzyrpa1M6e
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/jr6K_a9CRYg?si=h9rxdXWzyrpa1M6e
# Downloading video from URL: https://youtube.com/shorts/3PuwZ966qgg?si=mUlP4DaU3Dh2YJrG
# Error downloading video from URL https://youtube.com/shorts/3PuwZ966qgg?si=mUlP4DaU3Dh2YJrG: 3PuwZ966qgg is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/3PuwZ966qgg?si=mUlP4DaU3Dh2YJrG
# Downloading video from URL: https://youtube.com/shorts/n1w_d6vwKJQ?si=925OfUIr6YQE2hUO
# Error downloading video from URL https://youtube.com/shorts/n1w_d6vwKJQ?si=925OfUIr6YQE2hUO: n1w_d6vwKJQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/n1w_d6vwKJQ?si=925OfUIr6YQE2hUO
# Downloading video from URL: https://youtube.com/shorts/d9UUShUPEn8?si=w7nVf1spSQcHm_J0
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/d9UUShUPEn8?si=w7nVf1spSQcHm_J0
# Downloading video from URL: https://youtube.com/shorts/Yn613kBgMFk?si=o-jjzAMVEBjKhdPs
# Error downloading video from URL https://youtube.com/shorts/Yn613kBgMFk?si=o-jjzAMVEBjKhdPs: Yn613kBgMFk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Yn613kBgMFk?si=o-jjzAMVEBjKhdPs
# Downloading video from URL: https://youtube.com/shorts/PkCetDdWmNo?si=msj0Egj795FluzZx
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/PkCetDdWmNo?si=msj0Egj795FluzZx
# Downloading video from URL: https://youtube.com/shorts/VDFYB0lW9tg?si=0Zc60i_ziSlWG58t
# Video downloaded successfully!
# Video VDFYB0lW9tg_20240417052708.mp4 uploaded successfully!
# Video VDFYB0lW9tg_20240417052708.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/4I8LRAeK5q8?si=qLF2jPiQFdRABSun
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/4I8LRAeK5q8?si=qLF2jPiQFdRABSun
# Downloading video from URL: https://youtube.com/shorts/-15SwEbrM0M?si=qFnu6OFlZcy8tL9G
# Error downloading video from URL https://youtube.com/shorts/-15SwEbrM0M?si=qFnu6OFlZcy8tL9G: -15SwEbrM0M is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/-15SwEbrM0M?si=qFnu6OFlZcy8tL9G
# Downloading video from URL: https://youtube.com/shorts/KSMJh63AGjA?si=SebyEWy4dsMkopSH
# Video downloaded successfully!
# Video KSMJh63AGjA_20240417052715.mp4 uploaded successfully!
# Video KSMJh63AGjA_20240417052715.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/YLj-P5v5VjE?si=8N07iwUa1x_TV5K-
# Error downloading video from URL https://youtube.com/shorts/YLj-P5v5VjE?si=8N07iwUa1x_TV5K-: YLj-P5v5VjE is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/YLj-P5v5VjE?si=8N07iwUa1x_TV5K-
# Downloading video from URL: https://youtube.com/shorts/UDUicM61cp4?si=gzZaJPRXnxhIqdru
# Error downloading video from URL https://youtube.com/shorts/UDUicM61cp4?si=gzZaJPRXnxhIqdru: UDUicM61cp4 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/UDUicM61cp4?si=gzZaJPRXnxhIqdru
# Downloading video from URL: https://youtube.com/shorts/FiMtZBsAIZk?si=JL_IltyFubEHmDor
# Error downloading video from URL https://youtube.com/shorts/FiMtZBsAIZk?si=JL_IltyFubEHmDor: FiMtZBsAIZk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/FiMtZBsAIZk?si=JL_IltyFubEHmDor
# Downloading video from URL: https://youtube.com/shorts/cAGPjoBcfKY?si=OIcV0PhJveZhyBAy
# Error downloading video from URL https://youtube.com/shorts/cAGPjoBcfKY?si=OIcV0PhJveZhyBAy: cAGPjoBcfKY is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/cAGPjoBcfKY?si=OIcV0PhJveZhyBAy
# Downloading video from URL: https://youtube.com/shorts/1pNXJVb10Vk?si=_Io6mKsjjQ-CSnZz
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/1pNXJVb10Vk?si=_Io6mKsjjQ-CSnZz
# Downloading video from URL: https://youtube.com/shorts/IMGs9JL5mUs?si=cnOHBQNZlvhr0rOW
# Video downloaded successfully!
# Video IMGs9JL5mUs_20240417052730.mp4 uploaded successfully!
# Video IMGs9JL5mUs_20240417052730.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/HqTi2V3SbnE?si=eMM-xfxdfBg09rRC
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/HqTi2V3SbnE?si=eMM-xfxdfBg09rRC
# Downloading video from URL: https://youtube.com/shorts/pMiu7KQxLNE?si=W6lRQ8awEaUBAHyv
# Error downloading video from URL https://youtube.com/shorts/pMiu7KQxLNE?si=W6lRQ8awEaUBAHyv: pMiu7KQxLNE is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/pMiu7KQxLNE?si=W6lRQ8awEaUBAHyv
# Downloading video from URL: https://youtube.com/shorts/aJ1xFPehZKM?si=Tjogi1KarY-6BuKK
# Error downloading video from URL https://youtube.com/shorts/aJ1xFPehZKM?si=Tjogi1KarY-6BuKK: aJ1xFPehZKM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/aJ1xFPehZKM?si=Tjogi1KarY-6BuKK
# Downloading video from URL: https://youtube.com/shorts/14H6r5ZrVPs?si=gBhJJuNmYbDGuHOq
# Error downloading video from URL https://youtube.com/shorts/14H6r5ZrVPs?si=gBhJJuNmYbDGuHOq: 14H6r5ZrVPs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/14H6r5ZrVPs?si=gBhJJuNmYbDGuHOq
# Downloading video from URL: https://youtube.com/shorts/RPWoz6y593A?si=TIPRtYPTkOEj1bDV
# Error downloading video from URL https://youtube.com/shorts/RPWoz6y593A?si=TIPRtYPTkOEj1bDV: RPWoz6y593A is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/RPWoz6y593A?si=TIPRtYPTkOEj1bDV
# Downloading video from URL: https://youtube.com/shorts/9YYPcnuO4N8?si=txPsXgLMxz6QOdaE
# Error downloading video from URL https://youtube.com/shorts/9YYPcnuO4N8?si=txPsXgLMxz6QOdaE: 9YYPcnuO4N8 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/9YYPcnuO4N8?si=txPsXgLMxz6QOdaE
# Downloading video from URL: https://youtube.com/shorts/ha1--DO0B4g?si=uOEVaKcTVb-w8OcQ
# Error downloading video from URL https://youtube.com/shorts/ha1--DO0B4g?si=uOEVaKcTVb-w8OcQ: ha1--DO0B4g is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/ha1--DO0B4g?si=uOEVaKcTVb-w8OcQ
# Downloading video from URL: https://youtube.com/shorts/gtxPu_OZNrI?si=Hys2pXQzLr1A4xGS
# Error downloading video from URL https://youtube.com/shorts/gtxPu_OZNrI?si=Hys2pXQzLr1A4xGS: gtxPu_OZNrI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/gtxPu_OZNrI?si=Hys2pXQzLr1A4xGS
# Downloading video from URL: https://youtube.com/shorts/adQbLIOguWU?si=CrVQEpTFgenQakuI
# Video downloaded successfully!
# Video adQbLIOguWU_20240417052749.mp4 uploaded successfully!
# Video adQbLIOguWU_20240417052749.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/w-7uWB9MhKY?si=5spoLUq5nGLNKaIo
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/w-7uWB9MhKY?si=5spoLUq5nGLNKaIo
# Downloading video from URL: https://youtube.com/shorts/n0-GiApWWHI?si=GDPR_KIwxxXQq7PU
# Error downloading video from URL https://youtube.com/shorts/n0-GiApWWHI?si=GDPR_KIwxxXQq7PU: n0-GiApWWHI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/n0-GiApWWHI?si=GDPR_KIwxxXQq7PU
# Downloading video from URL: https://youtube.com/shorts/W0ghUzkvptc?si=USQhIE8l9b81bY5c
# Error downloading video from URL https://youtube.com/shorts/W0ghUzkvptc?si=USQhIE8l9b81bY5c: W0ghUzkvptc is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/W0ghUzkvptc?si=USQhIE8l9b81bY5c
# Downloading video from URL: https://youtube.com/shorts/NyCTwf5HVC8?si=BKYeX7Nkxz9G-9Q4
# Video downloaded successfully!
# Video NyCTwf5HVC8_20240417052756.mp4 uploaded successfully!
# Video NyCTwf5HVC8_20240417052756.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Ry_D6T5LFTM?si=nTuV0sY1fkyO4gTH
# Error downloading video from URL https://youtube.com/shorts/Ry_D6T5LFTM?si=nTuV0sY1fkyO4gTH: Ry_D6T5LFTM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Ry_D6T5LFTM?si=nTuV0sY1fkyO4gTH
# Downloading video from URL: https://youtube.com/shorts/ty_YoxlsvZw?si=RlG4EDb0u86-cyWo
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ty_YoxlsvZw?si=RlG4EDb0u86-cyWo
# Downloading video from URL: https://youtube.com/shorts/rlhELw54lJk?si=lyT8B9j0YJSKx9W5
# Error downloading video from URL https://youtube.com/shorts/rlhELw54lJk?si=lyT8B9j0YJSKx9W5: rlhELw54lJk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/rlhELw54lJk?si=lyT8B9j0YJSKx9W5
# Downloading video from URL: https://youtube.com/shorts/Hbr_Ys5h_cs?si=Lp9OOfMIb73A66Yg
# Error downloading video from URL https://youtube.com/shorts/Hbr_Ys5h_cs?si=Lp9OOfMIb73A66Yg: Hbr_Ys5h_cs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Hbr_Ys5h_cs?si=Lp9OOfMIb73A66Yg
# Downloading video from URL: https://youtube.com/shorts/3H_nnumPcsQ?si=EXzEfxNEaSP-R41K
# Error downloading video from URL https://youtube.com/shorts/3H_nnumPcsQ?si=EXzEfxNEaSP-R41K: 3H_nnumPcsQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/3H_nnumPcsQ?si=EXzEfxNEaSP-R41K
# Downloading video from URL: https://youtube.com/shorts/PvWZnZE8C2s?si=bUKN0iOFX535KZid
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/PvWZnZE8C2s?si=bUKN0iOFX535KZid
# Downloading video from URL: https://youtube.com/shorts/tkiu5BLrxa8?si=i4YFtcposv512jvm
# Error downloading video from URL https://youtube.com/shorts/tkiu5BLrxa8?si=i4YFtcposv512jvm: tkiu5BLrxa8 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/tkiu5BLrxa8?si=i4YFtcposv512jvm
# Downloading video from URL: https://youtube.com/shorts/YGi2VA5z7bA?si=OBjfVdeolCwYu0Wm
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/YGi2VA5z7bA?si=OBjfVdeolCwYu0Wm
# Downloading video from URL: https://youtube.com/shorts/Oq_k4YozO-Q?si=HDsnJ5GQgq62m7jZ
# Error downloading video from URL https://youtube.com/shorts/Oq_k4YozO-Q?si=HDsnJ5GQgq62m7jZ: Oq_k4YozO-Q is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Oq_k4YozO-Q?si=HDsnJ5GQgq62m7jZ
# Downloading video from URL: https://youtube.com/shorts/_9Ow9tzO2R4?si=v25-F8ThRZgOWPcz
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/_9Ow9tzO2R4?si=v25-F8ThRZgOWPcz
# Downloading video from URL: https://youtube.com/shorts/OgQQgvHCrxc?si=mYIA3PBT1RVx4GzI
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/OgQQgvHCrxc?si=mYIA3PBT1RVx4GzI
# Downloading video from URL: https://youtube.com/shorts/XoL9Bd3-8Vk?si=R1aXVFgETtNbT9Lt
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/XoL9Bd3-8Vk?si=R1aXVFgETtNbT9Lt
# Downloading video from URL: https://youtube.com/shorts/j2OZUsjQJr8?si=3xq8PbIxgCKvPwLx
# Error downloading video from URL https://youtube.com/shorts/j2OZUsjQJr8?si=3xq8PbIxgCKvPwLx: j2OZUsjQJr8 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/j2OZUsjQJr8?si=3xq8PbIxgCKvPwLx
# Downloading video from URL: https://youtube.com/shorts/8kHIjOkToQM?si=twsWrynKcX-8JqqY
# Error downloading video from URL https://youtube.com/shorts/8kHIjOkToQM?si=twsWrynKcX-8JqqY: 8kHIjOkToQM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/8kHIjOkToQM?si=twsWrynKcX-8JqqY
# Downloading video from URL: https://youtube.com/shorts/csxNV5UaG1s?si=uYSgTbGzn7PV3AbJ
# Error downloading video from URL https://youtube.com/shorts/csxNV5UaG1s?si=uYSgTbGzn7PV3AbJ: csxNV5UaG1s is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/csxNV5UaG1s?si=uYSgTbGzn7PV3AbJ
# Downloading video from URL: https://youtube.com/shorts/yMBBbY9cptI?si=Nz62rbPhLVnIu5-j
# Error downloading video from URL https://youtube.com/shorts/yMBBbY9cptI?si=Nz62rbPhLVnIu5-j: yMBBbY9cptI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/yMBBbY9cptI?si=Nz62rbPhLVnIu5-j
# Downloading video from URL: https://youtube.com/shorts/FtZ8lr0d7YY?si=jw9X8NIsV3KwSqNd
# Error downloading video from URL https://youtube.com/shorts/FtZ8lr0d7YY?si=jw9X8NIsV3KwSqNd: FtZ8lr0d7YY is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/FtZ8lr0d7YY?si=jw9X8NIsV3KwSqNd
# Downloading video from URL: https://youtube.com/shorts/lNTXk4SaTR0?si=3_KQjBynw81BSBTW
# Error downloading video from URL https://youtube.com/shorts/lNTXk4SaTR0?si=3_KQjBynw81BSBTW: lNTXk4SaTR0 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/lNTXk4SaTR0?si=3_KQjBynw81BSBTW
# Downloading video from URL: https://youtube.com/shorts/u8iWjVoxz-g?si=KCbhxQSpcY2dVUYQ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/u8iWjVoxz-g?si=KCbhxQSpcY2dVUYQ
# Downloading video from URL: https://youtube.com/shorts/bNy6TEy_U5c?si=tAIsb0qnagqVd6Ax
# Error downloading video from URL https://youtube.com/shorts/bNy6TEy_U5c?si=tAIsb0qnagqVd6Ax: bNy6TEy_U5c is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/bNy6TEy_U5c?si=tAIsb0qnagqVd6Ax
# Downloading video from URL: https://youtube.com/shorts/dZYTTit9rHE?si=oBorNi_AMSiO8cB1
# Error downloading video from URL https://youtube.com/shorts/dZYTTit9rHE?si=oBorNi_AMSiO8cB1: dZYTTit9rHE is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/dZYTTit9rHE?si=oBorNi_AMSiO8cB1
# Downloading video from URL: https://youtube.com/shorts/Tq0gvAeGBVs?si=rB0LoNKWkdB7IDS3
# Error downloading video from URL https://youtube.com/shorts/Tq0gvAeGBVs?si=rB0LoNKWkdB7IDS3: Tq0gvAeGBVs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Tq0gvAeGBVs?si=rB0LoNKWkdB7IDS3
# Downloading video from URL: https://youtube.com/shorts/ybu1I7CWDSw?si=hYqHuALDaHreN83N
# Error downloading video from URL https://youtube.com/shorts/ybu1I7CWDSw?si=hYqHuALDaHreN83N: ybu1I7CWDSw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/ybu1I7CWDSw?si=hYqHuALDaHreN83N
# Downloading video from URL: https://youtube.com/shorts/DIlD-FAf67Y?si=2CRetpEbb9pTPt1v
# Error downloading video from URL https://youtube.com/shorts/DIlD-FAf67Y?si=2CRetpEbb9pTPt1v: DIlD-FAf67Y is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/DIlD-FAf67Y?si=2CRetpEbb9pTPt1v
# Downloading video from URL: https://youtube.com/shorts/eJAo4k59am0?si=TNp-eJubgTrg0K06
# Error downloading video from URL https://youtube.com/shorts/eJAo4k59am0?si=TNp-eJubgTrg0K06: eJAo4k59am0 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/eJAo4k59am0?si=TNp-eJubgTrg0K06
# Downloading video from URL: https://youtube.com/shorts/wBWzphy1Q9U?si=vZvl387HRDsQKApW
# Error downloading video from URL https://youtube.com/shorts/wBWzphy1Q9U?si=vZvl387HRDsQKApW: wBWzphy1Q9U is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/wBWzphy1Q9U?si=vZvl387HRDsQKApW
# Downloading video from URL: https://youtube.com/shorts/4nRbk6AezXo?si=YRy1FFtlzosEkGfH
# Error downloading video from URL https://youtube.com/shorts/4nRbk6AezXo?si=YRy1FFtlzosEkGfH: 4nRbk6AezXo is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/4nRbk6AezXo?si=YRy1FFtlzosEkGfH
# Downloading video from URL: https://youtube.com/shorts/PnMJIX8Cc8k?si=afDr_fXoUpo--Ukq
# Error downloading video from URL https://youtube.com/shorts/PnMJIX8Cc8k?si=afDr_fXoUpo--Ukq: PnMJIX8Cc8k is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/PnMJIX8Cc8k?si=afDr_fXoUpo--Ukq
# Downloading video from URL: https://youtube.com/shorts/Jza4a5PZq5Y?si=YQ4T0hsNTvfq43id
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Jza4a5PZq5Y?si=YQ4T0hsNTvfq43id
# Downloading video from URL: https://youtube.com/shorts/7m79rLxx8fo?si=BTbZh_qnSrWzgo5D
# Error downloading video from URL https://youtube.com/shorts/7m79rLxx8fo?si=BTbZh_qnSrWzgo5D: 7m79rLxx8fo is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/7m79rLxx8fo?si=BTbZh_qnSrWzgo5D
# Downloading video from URL: https://youtube.com/shorts/ijbaGABynow?si=9msKK8sZQoZxETo
# Video downloaded successfully!
# Video ijbaGABynow_20240417052844.mp4 uploaded successfully!
# Video ijbaGABynow_20240417052844.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/YAODuGdHkBo?si=ENi5z_EU1JM46i4g
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/YAODuGdHkBo?si=ENi5z_EU1JM46i4g
# Downloading video from URL: https://youtube.com/shorts/fp3DqYFIhsc?si=m9mjESKAiJE4-Gji
# Video downloaded successfully!
# Video fp3DqYFIhsc_20240417052854.mp4 uploaded successfully!
# Video fp3DqYFIhsc_20240417052854.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/CNKsSAxl864?si=kWDhTcz_7uwc3VeG
# Error downloading video from URL https://youtube.com/shorts/CNKsSAxl864?si=kWDhTcz_7uwc3VeG: CNKsSAxl864 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/CNKsSAxl864?si=kWDhTcz_7uwc3VeG
# Downloading video from URL: https://youtube.com/shorts/HNXquaX40dU?si=pgXWvCQW6rOmMSUq
# Error downloading video from URL https://youtube.com/shorts/HNXquaX40dU?si=pgXWvCQW6rOmMSUq: HNXquaX40dU is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/HNXquaX40dU?si=pgXWvCQW6rOmMSUq
# Downloading video from URL: https://youtube.com/shorts/-rmS_TfZ_AM?si=cprrSPrvpyOD7Vft
# Video downloaded successfully!
# Video -rmS_TfZ_AM_20240417052902.mp4 uploaded successfully!
# Video -rmS_TfZ_AM_20240417052902.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/E4MqLxMo04s?si=YTpxgs_Ps2CLD5wp
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/E4MqLxMo04s?si=YTpxgs_Ps2CLD5wp
# Downloading video from URL: https://youtube.com/shorts/oZ4h2NV2Fmk?si=Mqma6cJiSQP-k6pw
# Error downloading video from URL https://youtube.com/shorts/oZ4h2NV2Fmk?si=Mqma6cJiSQP-k6pw: oZ4h2NV2Fmk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/oZ4h2NV2Fmk?si=Mqma6cJiSQP-k6pw
# Downloading video from URL: https://youtube.com/shorts/Q4Aj6PPwWSA?si=OIuqwWHUO1OcKYO7
# Error downloading video from URL https://youtube.com/shorts/Q4Aj6PPwWSA?si=OIuqwWHUO1OcKYO7: Q4Aj6PPwWSA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Q4Aj6PPwWSA?si=OIuqwWHUO1OcKYO7
# Downloading video from URL: https://youtube.com/shorts/11QzosqYf-Q?si=o65r2uSOm0xpyTiD
# Error downloading video from URL https://youtube.com/shorts/11QzosqYf-Q?si=o65r2uSOm0xpyTiD: 11QzosqYf-Q is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/11QzosqYf-Q?si=o65r2uSOm0xpyTiD
# Downloading video from URL: https://youtube.com/shorts/ucNLBfXzZsU?si=-QF8k7rzlWak47pj
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ucNLBfXzZsU?si=-QF8k7rzlWak47pj
# Downloading video from URL: https://youtube.com/shorts/VYJBshc1KWM?si=Q9nIGWevITJwl_en
# Error downloading video from URL https://youtube.com/shorts/VYJBshc1KWM?si=Q9nIGWevITJwl_en: VYJBshc1KWM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/VYJBshc1KWM?si=Q9nIGWevITJwl_en
# Downloading video from URL: https://youtube.com/shorts/VQV-QIGSZos?si=sSiiIrpDnz8aBCfa
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/VQV-QIGSZos?si=sSiiIrpDnz8aBCfa
# Downloading video from URL: https://youtube.com/shorts/hEpH1zAJyfs?si=PZmAoXHCRKRyifFa
# Error downloading video from URL https://youtube.com/shorts/hEpH1zAJyfs?si=PZmAoXHCRKRyifFa: hEpH1zAJyfs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/hEpH1zAJyfs?si=PZmAoXHCRKRyifFa
# Downloading video from URL: https://youtube.com/shorts/qqtwfe654PE?si=5yAzJZ-u2-PjuvFy
# Error downloading video from URL https://youtube.com/shorts/qqtwfe654PE?si=5yAzJZ-u2-PjuvFy: [Errno 36] File name too long: '/content/hindi/actor/𝗦𝗵𝗮𝗿𝗮𝗱 𝗠𝗮𝗹𝗵𝗼𝘁𝗿𝗮 𝗮𝘀 𝗔𝗱𝗶𝘁𝘆𝗮💫😘 6 𝘆𝗲𝗮𝗿𝘀 𝗼𝗳 𝗘𝗸 𝘁𝗲𝗿𝗮 𝘀𝗮𝗮𝘁𝗵 film💙𝗜𝗻 𝗠𝘆 𝗯𝗲𝗱 x snehithane 𝗦𝗼𝗻𝗴 𝗦𝘁𝗮𝘁𝘂𝘀 𝘀𝗵𝗼𝗿𝘁𝘀.mp4'
# Failed to download video from URL: https://youtube.com/shorts/qqtwfe654PE?si=5yAzJZ-u2-PjuvFy
# Downloading video from URL: https://youtube.com/shorts/5yhEiG3Bue0?si=lJM_xQWYjrHmRoU2
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/5yhEiG3Bue0?si=lJM_xQWYjrHmRoU2
# ...
# Video downloaded successfully!
# Video 9T1l5N9yyxw_20240417064855.mp4 uploaded successfully!
# Video 9T1l5N9yyxw_20240417064855.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0Imc_z9I_zc?si=i6nTEXZn3XbUhTRH
# Video downloaded successfully!
# Video 0Imc_z9I_zc_20240417064901.mp4 uploaded successfully!
# Video 0Imc_z9I_zc_20240417064901.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/6fy4jzGjJHM?si=xra1HdzbJ0fUl_Ra
# Video downloaded successfully!
# Video 6fy4jzGjJHM_20240417064908.mp4 uploaded successfully!
# Video 6fy4jzGjJHM_20240417064908.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/aX82sNFMe74?si=F0I0M-86Ydyt9UjE
# Video downloaded successfully!
# Video aX82sNFMe74_20240417064915.mp4 uploaded successfully!
# Video aX82sNFMe74_20240417064915.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/YXJg4l_qwNA?si=Cw1adQVba6YGNorM
# Error downloading video from URL https://youtube.com/shorts/YXJg4l_qwNA?si=Cw1adQVba6YGNorM: YXJg4l_qwNA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/YXJg4l_qwNA?si=Cw1adQVba6YGNorM
# Downloading video from URL: https://youtube.com/shorts/fHQ-bHBXTRk?si=6imPMmOWQmS3_UlK
# Error downloading video from URL https://youtube.com/shorts/fHQ-bHBXTRk?si=6imPMmOWQmS3_UlK: fHQ-bHBXTRk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/fHQ-bHBXTRk?si=6imPMmOWQmS3_UlK
# Downloading video from URL: https://youtube.com/shorts/hDbVbo56z5A?si=9A23JheKuBbREwoL
# Video downloaded successfully!
# Video hDbVbo56z5A_20240417064921.mp4 uploaded successfully!
# Video hDbVbo56z5A_20240417064921.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/sYla1S8wu8o?si=eCPIJeNpEAMr5Xmw
# Video downloaded successfully!
# Video sYla1S8wu8o_20240417064925.mp4 uploaded successfully!
# Video sYla1S8wu8o_20240417064925.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/EaEqca5BYvc?si=heS8BgnFkzgxa2kG
# Error downloading video from URL https://youtube.com/shorts/EaEqca5BYvc?si=heS8BgnFkzgxa2kG: EaEqca5BYvc is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/EaEqca5BYvc?si=heS8BgnFkzgxa2kG
# Downloading video from URL: https://youtube.com/shorts/LFMpSdlo9-0?si=Sw2ig4VRK49qkjsA
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/LFMpSdlo9-0?si=Sw2ig4VRK49qkjsA
# Downloading video from URL: https://youtube.com/shorts/SrDtsyp2FN0?si=IVWWpPUQA0FS9h5-
# Error downloading video from URL https://youtube.com/shorts/SrDtsyp2FN0?si=IVWWpPUQA0FS9h5-: SrDtsyp2FN0 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/SrDtsyp2FN0?si=IVWWpPUQA0FS9h5-
# Downloading video from URL: https://youtube.com/shorts/Dby9B0fRLSg?si=K9zt8SoCiiaCg47G
# Video downloaded successfully!
# Video Dby9B0fRLSg_20240417064939.mp4 uploaded successfully!
# Video Dby9B0fRLSg_20240417064939.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/rw9x-9vYcxQ?si=8bpPpvlRuzKPKhu9
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/rw9x-9vYcxQ?si=8bpPpvlRuzKPKhu9
# Downloading video from URL: https://youtube.com/shorts/7QdM7kELSJY?si=sH9PwLKQ3-DIy88L
# Error downloading video from URL https://youtube.com/shorts/7QdM7kELSJY?si=sH9PwLKQ3-DIy88L: 7QdM7kELSJY is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/7QdM7kELSJY?si=sH9PwLKQ3-DIy88L
# Downloading video from URL: https://youtube.com/shorts/AilwXiwKWSY?si=iJHo7FNnpsRTK_LL
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/AilwXiwKWSY?si=iJHo7FNnpsRTK_LL
# Downloading video from URL: https://youtube.com/shorts/vWI5cTGcGXA?si=w5gtVC6dDaatQaek
# Error downloading video from URL https://youtube.com/shorts/vWI5cTGcGXA?si=w5gtVC6dDaatQaek: vWI5cTGcGXA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/vWI5cTGcGXA?si=w5gtVC6dDaatQaek
# Downloading video from URL: https://youtube.com/shorts/LWjPOVZWf-Q?si=biThisBDPscq36d1
# Video downloaded successfully!
# Video LWjPOVZWf-Q_20240417064958.mp4 uploaded successfully!
# Video LWjPOVZWf-Q_20240417064958.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/bO_jz5JmFV0?si=ckoDh6ohnVsED0HI
# Video downloaded successfully!
# Video bO_jz5JmFV0_20240417065002.mp4 uploaded successfully!
# Video bO_jz5JmFV0_20240417065002.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/uLATatxs_4Y?si=zdtAtdfcHZiiliIB
# Video downloaded successfully!
# Video uLATatxs_4Y_20240417065008.mp4 uploaded successfully!
# Video uLATatxs_4Y_20240417065008.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/-iaYj9605sM?si=1Vps5Chqd1bwAtyF
# Error downloading video from URL https://youtube.com/shorts/-iaYj9605sM?si=1Vps5Chqd1bwAtyF: -iaYj9605sM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/-iaYj9605sM?si=1Vps5Chqd1bwAtyF
# Downloading video from URL: https://youtube.com/shorts/F_JMINGs3ho?si=1GcAxwXU-fidSbOx
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/F_JMINGs3ho?si=1GcAxwXU-fidSbOx
# Downloading video from URL: https://youtube.com/shorts/ysdeq9D-LO4?si=W-UStxBKYXMBI2db
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ysdeq9D-LO4?si=W-UStxBKYXMBI2db
# Downloading video from URL: https://youtube.com/shorts/ba5QzJBMscs?si=yE-1h1sWjftcES26
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ba5QzJBMscs?si=yE-1h1sWjftcES26
# Downloading video from URL: https://youtube.com/shorts/EeCYwwzabyk?si=ekwtTwB5bQnnP0Tp
# Error downloading video from URL https://youtube.com/shorts/EeCYwwzabyk?si=ekwtTwB5bQnnP0Tp: EeCYwwzabyk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/EeCYwwzabyk?si=ekwtTwB5bQnnP0Tp
# Downloading video from URL: https://youtube.com/shorts/UVAMTAJ9g8w?si=E12WagzR6atkL4mZ
# Video downloaded successfully!
# Video UVAMTAJ9g8w_20240417065024.mp4 uploaded successfully!
# Video UVAMTAJ9g8w_20240417065024.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/2-NuUXIXZM4?si=CLW9SeiKYZUzRL9l
# Video downloaded successfully!
# Video 2-NuUXIXZM4_20240417065033.mp4 uploaded successfully!
# Video 2-NuUXIXZM4_20240417065033.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/RZGS-BTVpU0?si=KJW2f-kcP9fVcySP
# Video downloaded successfully!
# Video RZGS-BTVpU0_20240417065038.mp4 uploaded successfully!
# Video RZGS-BTVpU0_20240417065038.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/RZGS-BTVpU0?si=7oe2kWMcozr1Siz0
# Video downloaded successfully!
# Video RZGS-BTVpU0_20240417065041.mp4 uploaded successfully!
# Video RZGS-BTVpU0_20240417065041.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/8fcjWrLR-gI?si=3viJEzDyPtD9SGwj
# Error downloading video from URL https://youtube.com/shorts/8fcjWrLR-gI?si=3viJEzDyPtD9SGwj: 8fcjWrLR-gI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/8fcjWrLR-gI?si=3viJEzDyPtD9SGwj
# Downloading video from URL: https://youtube.com/shorts/779vOl0Tk1Q?si=xKXF4kn0398ihTWw
# Video downloaded successfully!
# Video 779vOl0Tk1Q_20240417065047.mp4 uploaded successfully!
# Video 779vOl0Tk1Q_20240417065047.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/32hgCEoAPZU?si=THnED8MyMMEC5pCy
# Video downloaded successfully!
# Video 32hgCEoAPZU_20240417065052.mp4 uploaded successfully!
# Video 32hgCEoAPZU_20240417065052.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/CSpbt2poF8s?si=d2ohC82oNWG4XoxO
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/CSpbt2poF8s?si=d2ohC82oNWG4XoxO
# Downloading video from URL: https://youtube.com/shorts/BriDfwMw5vE?si=Oftjn_T4XcVtDfQf
# Error downloading video from URL https://youtube.com/shorts/BriDfwMw5vE?si=Oftjn_T4XcVtDfQf: BriDfwMw5vE is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/BriDfwMw5vE?si=Oftjn_T4XcVtDfQf
# Downloading video from URL: https://youtube.com/shorts/CWnyIHBGVEQ?si=UMmvZNr-1Q-yXWOw
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/CWnyIHBGVEQ?si=UMmvZNr-1Q-yXWOw
# Downloading video from URL: https://youtube.com/shorts/2AAzKVnNQAQ?si=0RL7zru9hitCZjaZ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/2AAzKVnNQAQ?si=0RL7zru9hitCZjaZ
# Downloading video from URL: https://youtube.com/shorts/DZlXNhCtUlc?si=VYMCPrbPGJ_PvjA6
# Video downloaded successfully!
# Video DZlXNhCtUlc_20240417065111.mp4 uploaded successfully!
# Video DZlXNhCtUlc_20240417065111.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/s_LtMI1RgJc?si=IiKL-7FsNP1grqHq
# Video downloaded successfully!
# Video s_LtMI1RgJc_20240417065115.mp4 uploaded successfully!
# Video s_LtMI1RgJc_20240417065115.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/BBVeekUExKE?si=4m-oFRG6uQnNjMLm
# Video downloaded successfully!
# Video BBVeekUExKE_20240417065124.mp4 uploaded successfully!
# Video BBVeekUExKE_20240417065124.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/WzgYn2004Rk?si=KuixAtkcKf0Kp7aq
# Video downloaded successfully!
# Video WzgYn2004Rk_20240417065131.mp4 uploaded successfully!
# Video WzgYn2004Rk_20240417065131.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/WbAJ09C12KE?si=6_vmD0EDCBN1Imn8
# Video downloaded successfully!
# Video WbAJ09C12KE_20240417065139.mp4 uploaded successfully!
# Video WbAJ09C12KE_20240417065139.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/tdxFvTqvIQA?si=kqhvRFrp7d_sn0kh
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/tdxFvTqvIQA?si=kqhvRFrp7d_sn0kh
# Downloading video from URL: https://youtube.com/shorts/rA4ncuWtLMg?si=X8ozE5uudd0WEmR8
# Video downloaded successfully!
# Video rA4ncuWtLMg_20240417065156.mp4 uploaded successfully!
# Video rA4ncuWtLMg_20240417065156.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/b7wuTCWINMo?si=2OV0v0XvNWkVgmtR
# Video downloaded successfully!
# Video b7wuTCWINMo_20240417065205.mp4 uploaded successfully!
# Video b7wuTCWINMo_20240417065205.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/tiQwfqRGTxo?si=XKdM0abVihom05nz
# Video downloaded successfully!
# Video tiQwfqRGTxo_20240417065212.mp4 uploaded successfully!
# Video tiQwfqRGTxo_20240417065212.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Ygh-YbB-OaQ?si=RjCRoEg9CMOxdz9S
# Video downloaded successfully!
# Video Ygh-YbB-OaQ_20240417065218.mp4 uploaded successfully!
# Video Ygh-YbB-OaQ_20240417065218.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/RUnbVC1TR-I?si=zyMTT8sPVyrVLVJ7
# Video downloaded successfully!
# Video RUnbVC1TR-I_20240417065226.mp4 uploaded successfully!
# Video RUnbVC1TR-I_20240417065226.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/PSbjMJ9Nnjg?si=fI0-7QOZJl4w9r7v
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/PSbjMJ9Nnjg?si=fI0-7QOZJl4w9r7v
# Downloading video from URL: https://youtube.com/shorts/Xts7QnvXDyA?si=J0GoPmUn4gsS-bOs
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Xts7QnvXDyA?si=J0GoPmUn4gsS-bOs
# Downloading video from URL: https://youtube.com/shorts/qrt93KorqOw?si=sv2_a-1GNDQGH4_w
# Video downloaded successfully!
# Video qrt93KorqOw_20240417065245.mp4 uploaded successfully!
# Video qrt93KorqOw_20240417065245.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/n3OeVmdfxSs?si=3Tzb1auNNS7r-3o0
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/n3OeVmdfxSs?si=3Tzb1auNNS7r-3o0
# Downloading video from URL: https://youtube.com/shorts/TJxq8ndvRuo?si=R91D8GNfOw19eIdz
# Video downloaded successfully!
# Video TJxq8ndvRuo_20240417065251.mp4 uploaded successfully!
# Video TJxq8ndvRuo_20240417065251.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/qZL-xGTDuIU?si=w2RbvWwC0Q02ORyY
# Video downloaded successfully!
# Video qZL-xGTDuIU_20240417065258.mp4 uploaded successfully!
# Video qZL-xGTDuIU_20240417065258.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/PF1VEPVJp2U?si=lvUf-qzycuyNFQvk
# Video downloaded successfully!
# Video PF1VEPVJp2U_20240417065305.mp4 uploaded successfully!
# Video PF1VEPVJp2U_20240417065305.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/UJ1DoUfkLA0?si=ymdjG0H7QIyC8jzZ
# Video downloaded successfully!
# Video UJ1DoUfkLA0_20240417065311.mp4 uploaded successfully!
# Video UJ1DoUfkLA0_20240417065311.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/mrvyDB3ncHg?si=OIpOPr7wT85XHi3N
# Error downloading video from URL https://youtube.com/shorts/mrvyDB3ncHg?si=OIpOPr7wT85XHi3N: mrvyDB3ncHg is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/mrvyDB3ncHg?si=OIpOPr7wT85XHi3N
# Downloading video from URL: https://youtube.com/shorts/vD-ShpycuCE?si=OO4NYK3CM9mu93uA
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/vD-ShpycuCE?si=OO4NYK3CM9mu93uA
# Downloading video from URL: https://youtube.com/shorts/XjBvsl3lXrs?si=tUwvpV_-bQvOS-6f
# Video downloaded successfully!
# Video XjBvsl3lXrs_20240417065324.mp4 uploaded successfully!
# Video XjBvsl3lXrs_20240417065324.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ruy5rA0gGM0?si=XDWhXlJBBP0f6tud
# Video downloaded successfully!
# Video ruy5rA0gGM0_20240417065336.mp4 uploaded successfully!
# Video ruy5rA0gGM0_20240417065336.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/8fm-9_OPNmY?si=ND6JbChn9pywTlH5
# Video downloaded successfully!
# Video 8fm-9_OPNmY_20240417065340.mp4 uploaded successfully!
# Video 8fm-9_OPNmY_20240417065340.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/us9njqyCQkk?si=wRyASI5uDDi9g08O
# Error downloading video from URL https://youtube.com/shorts/us9njqyCQkk?si=wRyASI5uDDi9g08O: us9njqyCQkk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/us9njqyCQkk?si=wRyASI5uDDi9g08O
# Downloading video from URL: https://youtube.com/shorts/oCDg2ZzEDwM?si=Q7BXl3MJnwU7NxeE
# Video downloaded successfully!
# Video oCDg2ZzEDwM_20240417065350.mp4 uploaded successfully!
# Video oCDg2ZzEDwM_20240417065350.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/qM4UYzWwp_U?si=ztKGxpKUwiV-1ZJQ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/qM4UYzWwp_U?si=ztKGxpKUwiV-1ZJQ
# Downloading video from URL: https://youtube.com/shorts/qRRffVAB6mE?si=CIwWHE5g5x3GhSlt
# Error downloading video from URL https://youtube.com/shorts/qRRffVAB6mE?si=CIwWHE5g5x3GhSlt: qRRffVAB6mE is unavailable
# Failed to download video from URL: https://youtube.com/shorts/qRRffVAB6mE?si=CIwWHE5g5x3GhSlt
# Upload report saved successfully.

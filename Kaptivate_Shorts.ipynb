# %% [markdown]
# <a href="https://colab.research.google.com/github/girinath18/youtube_shorts/blob/shorts_uploaded/Kaptivate_Shorts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import os
import re
from pytube import YouTube
import pandas as pd
import requests
import json
from datetime import datetime
import cv2

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def is_video_playable(file_path):
    """
    Check if the video file is playable using OpenCV.
    """
    try:
        cap = cv2.VideoCapture(file_path)
        if not cap.isOpened():
            return False
        ret, frame = cap.read()
        cap.release()
        return ret
    except Exception as e:
        print(f"Error checking video playability: {e}")
        return False

def download_youtube_shorts(url, output_folder):
    try:
        yt = YouTube(url)
        streams = yt.streams
        streams.filter(progressive=True)
        stream = streams.get_highest_resolution()
        if stream:
            # Download the video
            video_file = stream.download(output_folder)

            # Extract metadata
            title = clean_text(yt.title)
            description = clean_text(yt.description)
            video_id = yt.video_id

            # Generate file name with timestamp
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            new_filename = f"{video_id}_{timestamp}.mp4"
            new_filepath = os.path.join(output_folder, new_filename)
            os.rename(video_file, new_filepath)

            # Save metadata to a text file
            metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
            with open(metadata_file, "w") as f:
                f.write(f"Title: {title}\n")
                f.write(f"Description: {description}\n")
                f.write(f"Video ID: {video_id}\n")

            print("Video downloaded successfully!")

            return title, description, video_id, new_filename, new_filepath
        else:
            print("No suitable streams found for the video.")
            return None, None, None, None, None
    except Exception as e:
        print(f"Error downloading video from URL {url}: {e}")
        return None, None, None, None, None

def upload_video(file_name, file_path):
    try:
        # Read the binary data from the video file
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        # Headers with your access key
        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'  # Specify content type as binary
        }

        # Make a PUT request to the API endpoint with binary data in the request body
        response = requests.put(url + file_name, headers=headers, data=binary_data)

        # Check if the request was successful (status code 201)
        if response.status_code == 201:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        # Define headers with your access key
        headers = {
            'Content-Type': 'application/json',  # Specify content type as JSON
        }

        # Fetch views count from the YouTube video
        yt = YouTube(f"https://www.youtube.com/watch?v={file_name[:-4]}")
        views_count = yt.views

        # Define the JSON payload
        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,  # Using file_name directly
            "views": views_count  # Include views count in the payload
        }

        # Make a POST request to the API endpoint with binary data in the request body
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            print(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            print(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        print(f"Error uploading video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    # Read input file into a list of lines
    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        # Split each line by comma to get URL, Category, Subcategory
        parts = line.strip().split(',')
        # Take the first three fields, even if there are more
        if len(parts) < 3:
            print(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)

        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        print(f"Downloading video from URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        # Check if the download was successful
        if title and description and video_id and file_name and file_path:
            # Check if the video is playable
            if is_video_playable(file_path):
                # Call the function to upload the video
                if upload_video(file_name, file_path) and create_post(title, description, category, subcategory, file_name):
                    success_count += 1
                else:
                    failure_count += 1
            else:
                print(f"Video {file_name} is not playable and will not be uploaded.")
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            print(f"Failed to download video from URL: {url}")
            failure_count += 1

    # Convert the extracted data to a DataFrame
    extracted_df = pd.DataFrame(extracted_data)

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    print("Upload report saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Skipping line due to incorrect format:
#
# Downloading video from URL: https://youtube.com/shorts/XBrH1dQWp9I?si=S8Zw_hYEQs3InSbP
# Video downloaded successfully!
# Video XBrH1dQWp9I_20240610063104.mp4 uploaded successfully!
# Video XBrH1dQWp9I_20240610063104.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/E05VjdUOdfE?si=tfDPfHA3iSM6ZOIN
# Video downloaded successfully!
# Video E05VjdUOdfE_20240610063108.mp4 uploaded successfully!
# Video E05VjdUOdfE_20240610063108.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QezWEONS5mY?si=AnTWDrouyJWbC1Ew
# Video downloaded successfully!
# Video QezWEONS5mY_20240610063114.mp4 uploaded successfully!
# Video QezWEONS5mY_20240610063114.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/NKwMxhGJyd0?si=2Ye8wjjU7QannADX
# Video downloaded successfully!
# Video NKwMxhGJyd0_20240610063119.mp4 uploaded successfully!
# Video NKwMxhGJyd0_20240610063119.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/rKDKNxzsO7c?si=aYhuR1WSxViM8hIY
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/rKDKNxzsO7c?si=aYhuR1WSxViM8hIY
# Downloading video from URL: https://youtube.com/shorts/RPV-Sgu_xQU?si=vB7EARlhDDFbIK9p
# Video downloaded successfully!
# Video RPV-Sgu_xQU_20240610063126.mp4 uploaded successfully!
# Video RPV-Sgu_xQU_20240610063126.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Tf5UlHjor8M?si=5XTDr4fpOifRaIHU
# Video downloaded successfully!
# Video Tf5UlHjor8M_20240610063146.mp4 uploaded successfully!
# Video Tf5UlHjor8M_20240610063146.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/2IWtkMllyIg?si=1uUmFSmt_8eXttVc
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/2IWtkMllyIg?si=1uUmFSmt_8eXttVc
# Downloading video from URL: https://youtube.com/shorts/g5-qjD686OU?si=9qP92FBh95YaxV1o
# Error downloading video from URL https://youtube.com/shorts/g5-qjD686OU?si=9qP92FBh95YaxV1o: g5-qjD686OU is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/g5-qjD686OU?si=9qP92FBh95YaxV1o
# Downloading video from URL: https://youtube.com/shorts/Mc3ruW6-ZdM?si=swA0KHthumjwpL2Q
# Video downloaded successfully!
# Video Mc3ruW6-ZdM_20240610063239.mp4 uploaded successfully!
# Video Mc3ruW6-ZdM_20240610063239.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0i7mRotrjAY?si=brWcDRr-gt5thA-G
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/0i7mRotrjAY?si=brWcDRr-gt5thA-G
# Downloading video from URL: https://youtube.com/shorts/ex0yEGtIdR8?si=lxj6kYljiiHhmVUH
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ex0yEGtIdR8?si=lxj6kYljiiHhmVUH
# Downloading video from URL: https://youtube.com/shorts/ntI8oH0Ejo4?si=9PkhBJZJ7BQraNrO
# Error downloading video from URL https://youtube.com/shorts/ntI8oH0Ejo4?si=9PkhBJZJ7BQraNrO: ntI8oH0Ejo4 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/ntI8oH0Ejo4?si=9PkhBJZJ7BQraNrO
# Downloading video from URL: https://youtube.com/shorts/aX1kr-WS-YU?si=ReyX7IrYzg4ZMSYs
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/aX1kr-WS-YU?si=ReyX7IrYzg4ZMSYs
# Downloading video from URL: https://youtube.com/shorts/6ClfLmBKXCQ?si=2SbUI_DK-AM2DoXG
# Error downloading video from URL https://youtube.com/shorts/6ClfLmBKXCQ?si=2SbUI_DK-AM2DoXG: 6ClfLmBKXCQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/6ClfLmBKXCQ?si=2SbUI_DK-AM2DoXG
# Downloading video from URL: https://youtube.com/shorts/FrISYrn7_t4?si=Bba-tnSRMbdZS7HZ
# Video downloaded successfully!
# Video FrISYrn7_t4_20240610063259.mp4 uploaded successfully!
# Video FrISYrn7_t4_20240610063259.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/nf_FqHMX8cw?si=QsfKbOZxppXn8w1O
# Video downloaded successfully!
# Video nf_FqHMX8cw_20240610063304.mp4 uploaded successfully!
# Video nf_FqHMX8cw_20240610063304.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/7gLxzWQPig0?si=0v5qtuXkf9JMHFSY
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/7gLxzWQPig0?si=0v5qtuXkf9JMHFSY
# Downloading video from URL: https://youtube.com/shorts/GB39nwdoPCk?si=J46GDnKNzXnNWrCU
# Error downloading video from URL https://youtube.com/shorts/GB39nwdoPCk?si=J46GDnKNzXnNWrCU: GB39nwdoPCk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/GB39nwdoPCk?si=J46GDnKNzXnNWrCU
# Downloading video from URL: https://youtube.com/shorts/N_huJ5nlHac?si=CoDILUTcfDsXYGxK
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/N_huJ5nlHac?si=CoDILUTcfDsXYGxK
# Downloading video from URL: https://youtube.com/shorts/TB3x6LHluj4?si=L07E8xPHe7U6tD29
# Video downloaded successfully!
# Video TB3x6LHluj4_20240610063333.mp4 uploaded successfully!
# Video TB3x6LHluj4_20240610063333.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/TnyfXak9dbs?si=qXvh_4T6qZe7Z2t9
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/TnyfXak9dbs?si=qXvh_4T6qZe7Z2t9
# Downloading video from URL: https://youtube.com/shorts/f0yeTtnJiRA?si=enJoiWJD69AGs7T1
# Video downloaded successfully!
# Video f0yeTtnJiRA_20240610063341.mp4 uploaded successfully!
# Video f0yeTtnJiRA_20240610063341.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/XbIt_n8WA7w?si=4pgSaeSn1kKPVbKC
# Video downloaded successfully!
# Video XbIt_n8WA7w_20240610063345.mp4 uploaded successfully!
# Video XbIt_n8WA7w_20240610063345.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/zWwnmvipRIk?si=7dWCpscWfac3cstq
# Error downloading video from URL https://youtube.com/shorts/zWwnmvipRIk?si=7dWCpscWfac3cstq: zWwnmvipRIk is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/zWwnmvipRIk?si=7dWCpscWfac3cstq
# Downloading video from URL: https://youtube.com/shorts/_wJ1Wszv1b8?si=30XVhGgnxezdJ7sE
# Error downloading video from URL https://youtube.com/shorts/_wJ1Wszv1b8?si=30XVhGgnxezdJ7sE: _wJ1Wszv1b8 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/_wJ1Wszv1b8?si=30XVhGgnxezdJ7sE
# Downloading video from URL: https://youtube.com/shorts/yXJVOEbzVeI?si=4jBixJK6Wham75X1
# Error downloading video from URL https://youtube.com/shorts/yXJVOEbzVeI?si=4jBixJK6Wham75X1: yXJVOEbzVeI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/yXJVOEbzVeI?si=4jBixJK6Wham75X1
# Downloading video from URL: https://youtube.com/shorts/rL5iWRjMB_c?si=WKc-LfVN8xYgacs0
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/rL5iWRjMB_c?si=WKc-LfVN8xYgacs0
# Downloading video from URL: https://youtube.com/shorts/5WYq5Uyp8sk?si=NY1h4TmdzN7CVFQ7
# Video downloaded successfully!
# Video 5WYq5Uyp8sk_20240610063402.mp4 uploaded successfully!
# Video 5WYq5Uyp8sk_20240610063402.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Ceb6g77MnzU?si=dJsR491AT4EWWDEI
# Video downloaded successfully!
# Video Ceb6g77MnzU_20240610063406.mp4 uploaded successfully!
# Video Ceb6g77MnzU_20240610063406.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/uiDfK0YZWh0?si=sMq5otMdgy5M2iou
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/uiDfK0YZWh0?si=sMq5otMdgy5M2iou
# Downloading video from URL: https://youtube.com/shorts/Y21HrDsyDTk?si=nSbC_-CklLLXd6rk
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Y21HrDsyDTk?si=nSbC_-CklLLXd6rk
# Downloading video from URL: https://youtube.com/shorts/nsuDQMzZoNQ?si=Ln92wrHs1seCFdDi
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/nsuDQMzZoNQ?si=Ln92wrHs1seCFdDi
# Downloading video from URL: https://youtube.com/shorts/7pQ6U3cu0f4?si=tQ6DjNKKwvJLU87O
# Error downloading video from URL https://youtube.com/shorts/7pQ6U3cu0f4?si=tQ6DjNKKwvJLU87O: 7pQ6U3cu0f4 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/7pQ6U3cu0f4?si=tQ6DjNKKwvJLU87O
# Downloading video from URL: https://youtube.com/shorts/lEHTw5RR-Bw?si=s1oHCzgH_2hG3lnv
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/lEHTw5RR-Bw?si=s1oHCzgH_2hG3lnv
# Downloading video from URL: https://youtube.com/shorts/ilwk4dL8es8?si=PV8qy41xrIEe2Tdb
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ilwk4dL8es8?si=PV8qy41xrIEe2Tdb
# Downloading video from URL: https://youtube.com/shorts/qpGRW4bg1t0?si=voxIkVxmIOE4lEB5
# Error downloading video from URL https://youtube.com/shorts/qpGRW4bg1t0?si=voxIkVxmIOE4lEB5: qpGRW4bg1t0 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/qpGRW4bg1t0?si=voxIkVxmIOE4lEB5
# Downloading video from URL: https://youtube.com/shorts/QrZ8aMTi_ms?si=ZDzpNQQ529DTmuTK
# Error downloading video from URL https://youtube.com/shorts/QrZ8aMTi_ms?si=ZDzpNQQ529DTmuTK: QrZ8aMTi_ms is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/QrZ8aMTi_ms?si=ZDzpNQQ529DTmuTK
# Downloading video from URL: https://youtube.com/shorts/EiailFJs7ZA?si=AmaCIggjfOerosvp
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/EiailFJs7ZA?si=AmaCIggjfOerosvp
# Downloading video from URL: https://youtube.com/shorts/a4VfLQ9PUlY?si=Q5kRWc1k7vi-Fgy_
# Video downloaded successfully!
# Video a4VfLQ9PUlY_20240610063440.mp4 uploaded successfully!
# Video a4VfLQ9PUlY_20240610063440.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Qrhs0aItv5w?si=KQFFeYmkkaJPZ9cH
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Qrhs0aItv5w?si=KQFFeYmkkaJPZ9cH
# Downloading video from URL: https://youtube.com/shorts/OEb2DRx8bsI?si=SuXu1Zh8-SPvJmDS
# Video downloaded successfully!
# Video OEb2DRx8bsI_20240610063504.mp4 uploaded successfully!
# Video OEb2DRx8bsI_20240610063504.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/EA1aiS7gXDk?si=2wUCzFvvZhUUpg3y
# Video downloaded successfully!
# Video EA1aiS7gXDk_20240610063510.mp4 uploaded successfully!
# Video EA1aiS7gXDk_20240610063510.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/_HcySPAYaMk?si=7sqKnEh5AyIAPQom
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/_HcySPAYaMk?si=7sqKnEh5AyIAPQom
# Downloading video from URL: https://youtube.com/shorts/WfpeQyL9B-A?si=tP6xlKRzrdS54kF8
# Video downloaded successfully!
# Video WfpeQyL9B-A_20240610063520.mp4 uploaded successfully!
# Video WfpeQyL9B-A_20240610063520.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ZTrfomzENEQ?si=dpOtHetR4Tezt2oq
# Video downloaded successfully!
# Video ZTrfomzENEQ_20240610063526.mp4 uploaded successfully!
# Video ZTrfomzENEQ_20240610063526.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/HujkhAL7mS4?si=UwVTRkLDLpG_3GHP
# Video downloaded successfully!
# Video HujkhAL7mS4_20240610063531.mp4 uploaded successfully!
# Video HujkhAL7mS4_20240610063531.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/OQ_B-Ne_S30?si=fyvf2rffe2AkgK0C
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/OQ_B-Ne_S30?si=fyvf2rffe2AkgK0C
# Downloading video from URL: https://youtube.com/shorts/ox-Kjp8Yc6s?si=IsFhzObN_MxmMCo1
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ox-Kjp8Yc6s?si=IsFhzObN_MxmMCo1
# Downloading video from URL: https://youtube.com/shorts/KEmfacVk2FU?si=DGGcN7-eSFGFT-N6
# Video downloaded successfully!
# Video KEmfacVk2FU_20240610063540.mp4 uploaded successfully!
# Video KEmfacVk2FU_20240610063540.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/sTaGwVVPGmc?si=xpRKEIKF4YUupfOr
# Video downloaded successfully!
# Video sTaGwVVPGmc_20240610063559.mp4 uploaded successfully!
# Video sTaGwVVPGmc_20240610063559.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0FmrVqPnMGw?si=xeBY4cli8dkpdFu7
# Video downloaded successfully!
# Video 0FmrVqPnMGw_20240610063608.mp4 uploaded successfully!
# Video 0FmrVqPnMGw_20240610063608.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/VdOUyK4szCI?si=6hO9KSwaPecJwv6i
# Video downloaded successfully!
# Video VdOUyK4szCI_20240610063639.mp4 uploaded successfully!
# Video VdOUyK4szCI_20240610063639.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/N_jcnw88-qg?si=yuOFIQX8FrGp4Nbh
# Video downloaded successfully!
# Video N_jcnw88-qg_20240610063644.mp4 uploaded successfully!
# Video N_jcnw88-qg_20240610063644.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/UQBuDBIcaP8?si=-wsYgHx8eenhIXxo
# Video downloaded successfully!
# Video UQBuDBIcaP8_20240610063707.mp4 uploaded successfully!
# Video UQBuDBIcaP8_20240610063707.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/622brKEK0Qg?si=9aUFgRfFInEp1EMz
# Video downloaded successfully!
# Video 622brKEK0Qg_20240610063711.mp4 uploaded successfully!
# Video 622brKEK0Qg_20240610063711.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/qw6G-uSPcRM?si=eAmHz1sUFT8hueSQ
# Video downloaded successfully!
# Video qw6G-uSPcRM_20240610063717.mp4 uploaded successfully!
# Video qw6G-uSPcRM_20240610063717.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0XPIipJM2Eo?si=Ye_Gu2GJ1PZSnIOq
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/0XPIipJM2Eo?si=Ye_Gu2GJ1PZSnIOq
# Downloading video from URL: https://youtube.com/shorts/HB6Z211-OXw?si=5KtUp29UIMOhvbwU
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/HB6Z211-OXw?si=5KtUp29UIMOhvbwU
# Downloading video from URL: https://youtube.com/shorts/Ui8SrM2tCW4?si=ux5WLheElRYhoamD
# Video downloaded successfully!
# Video Ui8SrM2tCW4_20240610063732.mp4 uploaded successfully!
# Video Ui8SrM2tCW4_20240610063732.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/xlOT2NkdG3I?si=NFQeugAYbCyvn4Oh
# Error downloading video from URL https://youtube.com/shorts/xlOT2NkdG3I?si=NFQeugAYbCyvn4Oh: xlOT2NkdG3I is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/xlOT2NkdG3I?si=NFQeugAYbCyvn4Oh
# Downloading video from URL: https://youtube.com/shorts/JHa1toBVTPM?si=oO_90LrDM1SvDpP6
# Video downloaded successfully!
# Video JHa1toBVTPM_20240610063738.mp4 uploaded successfully!
# Video JHa1toBVTPM_20240610063738.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/VHos3DdEpAw?si=0yArPNowMCmqRAfs
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/VHos3DdEpAw?si=0yArPNowMCmqRAfs
# Downloading video from URL: https://youtube.com/shorts/CVWTqhPJNSs?si=Qz0Cxdmd6ZBKdh8C
# Error downloading video from URL https://youtube.com/shorts/CVWTqhPJNSs?si=Qz0Cxdmd6ZBKdh8C: CVWTqhPJNSs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/CVWTqhPJNSs?si=Qz0Cxdmd6ZBKdh8C
# Downloading video from URL: https://youtube.com/shorts/SRk1RfcQArY?si=vq4XZ7TXh2X4-L8a
# Video downloaded successfully!
# Video SRk1RfcQArY_20240610063748.mp4 uploaded successfully!
# Video SRk1RfcQArY_20240610063748.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/OiXVzPQZukg?si=z1KdA0UQXHtZMJjp
# Video downloaded successfully!
# Video OiXVzPQZukg_20240610063751.mp4 uploaded successfully!
# Video OiXVzPQZukg_20240610063751.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/xyMC9mWtrQg?si=6jEueO_T0gOGkXQj
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/xyMC9mWtrQg?si=6jEueO_T0gOGkXQj
# Downloading video from URL: https://youtube.com/shorts/b8KxHVoQufs?si=MlORoscjpRvM5Wvt
# Video downloaded successfully!
# Video b8KxHVoQufs_20240610063812.mp4 uploaded successfully!
# Video b8KxHVoQufs_20240610063812.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/wSVYMx2KE9M?si=c753rN8F_a2DkWER
# Video downloaded successfully!
# Video wSVYMx2KE9M_20240610063819.mp4 uploaded successfully!
# Video wSVYMx2KE9M_20240610063819.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/4sLcdKhrqww?si=6o4OjKXbrOmurBny
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/4sLcdKhrqww?si=6o4OjKXbrOmurBny
# Downloading video from URL: https://youtube.com/shorts/OI3IuwxRQW4?si=Xyuo156yncKMseDj
# Video downloaded successfully!
# Video OI3IuwxRQW4_20240610063833.mp4 uploaded successfully!
# Video OI3IuwxRQW4_20240610063833.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/K9H04FJlkVc?si=5VNLVpiStQnrgbNa
# Video downloaded successfully!
# Video K9H04FJlkVc_20240610063839.mp4 uploaded successfully!
# Video K9H04FJlkVc_20240610063839.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/woZj5itA14E?si=jV5XSixpxNimCZIi
# Error downloading video from URL https://youtube.com/shorts/woZj5itA14E?si=jV5XSixpxNimCZIi: woZj5itA14E is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/woZj5itA14E?si=jV5XSixpxNimCZIi
# Downloading video from URL: https://youtube.com/shorts/--cy9nzhIjI?si=qRcJ9KYqV6rOgbl5
# Video downloaded successfully!
# Video --cy9nzhIjI_20240610063934.mp4 uploaded successfully!
# Video --cy9nzhIjI_20240610063934.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/EN-ojcGfmcI?si=F1DdVF_fnevThzxd
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/EN-ojcGfmcI?si=F1DdVF_fnevThzxd
# Downloading video from URL: https://youtube.com/shorts/MyW_zvNK4xA?si=hfnb9mN-QVR_97Nw
# Error downloading video from URL https://youtube.com/shorts/MyW_zvNK4xA?si=hfnb9mN-QVR_97Nw: MyW_zvNK4xA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/MyW_zvNK4xA?si=hfnb9mN-QVR_97Nw
# Downloading video from URL: https://youtube.com/shorts/r03lj_hX6Wk?si=tBrGhYptC2C9SERw
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/r03lj_hX6Wk?si=tBrGhYptC2C9SERw
# Downloading video from URL: https://youtube.com/shorts/VckmEr7sZHw?si=i9XS0dSYdN-hnWoc
# Video downloaded successfully!
# Video VckmEr7sZHw_20240610064014.mp4 uploaded successfully!
# Video VckmEr7sZHw_20240610064014.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/GJUvRpGukO8?si=JETQu2GxWen2B3hA
# Video downloaded successfully!
# Video GJUvRpGukO8_20240610064022.mp4 uploaded successfully!
# Video GJUvRpGukO8_20240610064022.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/j4nvGSX6_Tw?si=-EY6Ei6J3remb-cc
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/j4nvGSX6_Tw?si=-EY6Ei6J3remb-cc
# Downloading video from URL: https://youtube.com/shorts/DYwQbHNRTnk?si=UtdtGFBkk0TQOiiy
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/DYwQbHNRTnk?si=UtdtGFBkk0TQOiiy
# Downloading video from URL: https://youtube.com/shorts/L9ZOIC2Z-EM?si=wL1kjLaXqwVVvV1N
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/L9ZOIC2Z-EM?si=wL1kjLaXqwVVvV1N
# Downloading video from URL: https://youtube.com/shorts/DdwaW5gYe5o?si=73gWXK7jqDMkLI-d
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/DdwaW5gYe5o?si=73gWXK7jqDMkLI-d
# Downloading video from URL: https://youtube.com/shorts/slZFgWP9t_w?si=BsqvL9KTYk6SYln_
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/slZFgWP9t_w?si=BsqvL9KTYk6SYln_
# Downloading video from URL: https://youtube.com/shorts/dgf3ZX8xQTE?si=LJOyOoHJGgD3ezi0
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/dgf3ZX8xQTE?si=LJOyOoHJGgD3ezi0
# Downloading video from URL: https://youtube.com/shorts/yxOridBVLFE?si=Cx1Ny7n-BP7nEU5v
# Video downloaded successfully!
# Video yxOridBVLFE_20240610064112.mp4 uploaded successfully!
# Video yxOridBVLFE_20240610064112.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/-O9Nrh4hZ_o?si=2hCAPYOziEu9lgqV
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/-O9Nrh4hZ_o?si=2hCAPYOziEu9lgqV
# Downloading video from URL: https://youtube.com/shorts/k9yCZtf97OY?si=dwxtayQd7BD-gyMo
# Video downloaded successfully!
# Video k9yCZtf97OY_20240610064120.mp4 uploaded successfully!
# Video k9yCZtf97OY_20240610064120.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Z0ZnIcoTlXA?si=wWAvCyOW6O5pEyx4
# Error downloading video from URL https://youtube.com/shorts/Z0ZnIcoTlXA?si=wWAvCyOW6O5pEyx4: Z0ZnIcoTlXA is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/Z0ZnIcoTlXA?si=wWAvCyOW6O5pEyx4
# Downloading video from URL: https://youtube.com/shorts/Ry8iunKijKQ?si=YxzhHBAOPPwonR2u
# Video downloaded successfully!
# Video Ry8iunKijKQ_20240610064127.mp4 uploaded successfully!
# Video Ry8iunKijKQ_20240610064127.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/2p9vm_Rcct4?si=_BSbyvx8xSJFo49N
# Video downloaded successfully!
# Video 2p9vm_Rcct4_20240610064132.mp4 uploaded successfully!
# Video 2p9vm_Rcct4_20240610064132.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/IYIp0dqq4Gk?si=c-a_bLoZX4zjIgBo
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/IYIp0dqq4Gk?si=c-a_bLoZX4zjIgBo
# Downloading video from URL: https://youtube.com/shorts/8EthJNn1hWM?si=7YFx_YjjbeLQ_R6o
# Video downloaded successfully!
# Video 8EthJNn1hWM_20240610064142.mp4 uploaded successfully!
# Video 8EthJNn1hWM_20240610064142.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/9Yh_Jsc8PE8?si=vhva6GcR1agtrcnj
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/9Yh_Jsc8PE8?si=vhva6GcR1agtrcnj
# Downloading video from URL: https://youtube.com/shorts/HcH8kpAYBVM?si=H0jWXOHovrNYJP89
# Error downloading video from URL https://youtube.com/shorts/HcH8kpAYBVM?si=H0jWXOHovrNYJP89: HcH8kpAYBVM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/HcH8kpAYBVM?si=H0jWXOHovrNYJP89
# Downloading video from URL: https://youtube.com/shorts/dcdQmOEKSCY?si=RPxgE7jLsckrr_HV
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/dcdQmOEKSCY?si=RPxgE7jLsckrr_HV
# Downloading video from URL: https://youtube.com/shorts/m_RPGwGpcgs?si=eOLlmdld0gPKAymA
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/m_RPGwGpcgs?si=eOLlmdld0gPKAymA
# Downloading video from URL: https://youtube.com/shorts/2cASRh0EJuw?si=lpMaSxAwEDyzRDcR
# Error downloading video from URL https://youtube.com/shorts/2cASRh0EJuw?si=lpMaSxAwEDyzRDcR: 2cASRh0EJuw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/2cASRh0EJuw?si=lpMaSxAwEDyzRDcR
# Downloading video from URL: https://youtube.com/shorts/12aJ73Izr6c?si=Hk78FPGdmN_HLDnm
# Video downloaded successfully!
# Video 12aJ73Izr6c_20240610064207.mp4 uploaded successfully!
# Video 12aJ73Izr6c_20240610064207.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/WgRpOrcE9nI?si=grNJcWN6EiCvzHA5
# Video downloaded successfully!
# Video WgRpOrcE9nI_20240610064212.mp4 uploaded successfully!
# Video WgRpOrcE9nI_20240610064212.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/SZt7zZKHWSA?si=uAp6kxtcPAyVHECG
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/SZt7zZKHWSA?si=uAp6kxtcPAyVHECG
# Downloading video from URL: https://youtube.com/shorts/1042WU6J7Yk?si=4hM39BBIN8GGU655
# Video downloaded successfully!
# Video 1042WU6J7Yk_20240610064223.mp4 uploaded successfully!
# Video 1042WU6J7Yk_20240610064223.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/RfQIcRD8fYU?si=B6o1qEgC6_Wp2Fcg
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/RfQIcRD8fYU?si=B6o1qEgC6_Wp2Fcg
# Downloading video from URL: https://youtube.com/shorts/kUhqUOfOQBg?si=m4qzY2DnZrfRmRRA
# Error downloading video from URL https://youtube.com/shorts/kUhqUOfOQBg?si=m4qzY2DnZrfRmRRA: kUhqUOfOQBg is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/kUhqUOfOQBg?si=m4qzY2DnZrfRmRRA
# Downloading video from URL: https://youtube.com/shorts/vD0uMUn-gOI?si=FzKbMtnVXBKdV3hS
# Video downloaded successfully!
# Video vD0uMUn-gOI_20240610064237.mp4 uploaded successfully!
# Video vD0uMUn-gOI_20240610064237.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/gSxHD8zLh68?si=Hs7FIr70S2aq9Lw6
# Video downloaded successfully!
# Video gSxHD8zLh68_20240610064243.mp4 uploaded successfully!
# Video gSxHD8zLh68_20240610064243.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/pdEgbajQaEI?si=0Dx0qh6sAbeY-O6H
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/pdEgbajQaEI?si=0Dx0qh6sAbeY-O6H
# Downloading video from URL: https://youtube.com/shorts/1u5hZEZEMNw?si=_sJnYXsK7dFXiazm
# Error downloading video from URL https://youtube.com/shorts/1u5hZEZEMNw?si=_sJnYXsK7dFXiazm: 1u5hZEZEMNw is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/1u5hZEZEMNw?si=_sJnYXsK7dFXiazm
# Downloading video from URL: https://youtube.com/shorts/JbI8gyMuutg?si=VtKL08Jtg_2fPeu-
# Video downloaded successfully!
# Video JbI8gyMuutg_20240610064253.mp4 uploaded successfully!
# Video JbI8gyMuutg_20240610064253.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/BuztQNvUc_s?si=xxIjQ13EKjYoLOyL
# Video downloaded successfully!
# Video BuztQNvUc_s_20240610064312.mp4 uploaded successfully!
# Video BuztQNvUc_s_20240610064312.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/nP2vvpR0iIE?si=09vHIcURQSbArNpa
# Video downloaded successfully!
# Video nP2vvpR0iIE_20240610064317.mp4 uploaded successfully!
# Video nP2vvpR0iIE_20240610064317.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/MUzq7LUTLrk?si=kw2RPk9GvmsQGgJe
# Video downloaded successfully!
# Video MUzq7LUTLrk_20240610064323.mp4 uploaded successfully!
# Video MUzq7LUTLrk_20240610064323.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/2lrtWLwCHTA?si=2q62XRuKOfZ9UcxS
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/2lrtWLwCHTA?si=2q62XRuKOfZ9UcxS
# Downloading video from URL: https://youtube.com/shorts/F1q8DzuwYOs?si=57rgOAO4q-auJcVM
# Video downloaded successfully!
# Video F1q8DzuwYOs_20240610064332.mp4 uploaded successfully!
# Video F1q8DzuwYOs_20240610064332.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/G6FUkG73us4?si=rVaYcxXa3vQ2UZKz
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/G6FUkG73us4?si=rVaYcxXa3vQ2UZKz
# Downloading video from URL: https://youtube.com/shorts/gnB5bLcIjJ8?si=UFhNMoXLEf5t44pC
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/gnB5bLcIjJ8?si=UFhNMoXLEf5t44pC
# Downloading video from URL: https://youtube.com/shorts/d5ZL59h5xcc?si=vd3dSx15mEzrW8Ca
# Video downloaded successfully!
# Video d5ZL59h5xcc_20240610064341.mp4 uploaded successfully!
# Video d5ZL59h5xcc_20240610064341.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/VaXYVweANEs?si=vADdrgQRe8b-UzTF
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/VaXYVweANEs?si=vADdrgQRe8b-UzTF
# Downloading video from URL: https://youtube.com/shorts/pyCSq_BF4gI?si=pxAu2R8L5Wl9aNDH
# Video downloaded successfully!
# Video pyCSq_BF4gI_20240610064351.mp4 uploaded successfully!
# Video pyCSq_BF4gI_20240610064351.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/oZqpM9Tu-X4?si=DJItHMtA8R0xy53V
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/oZqpM9Tu-X4?si=DJItHMtA8R0xy53V
# Downloading video from URL: https://youtube.com/shorts/XE_9LH7cEB0?si=G9NB1r5JdXHG9OTY
# Video downloaded successfully!
# Video XE_9LH7cEB0_20240610064415.mp4 uploaded successfully!
# Video XE_9LH7cEB0_20240610064415.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/fBWh-S1p_tE?si=nh7SLlE8QVma9bVT
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/fBWh-S1p_tE?si=nh7SLlE8QVma9bVT
# Downloading video from URL: https://youtube.com/shorts/BB9iZsVqDGg?si=WEEmS4Cio2zw6PB1
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/BB9iZsVqDGg?si=WEEmS4Cio2zw6PB1
# Downloading video from URL: https://youtube.com/shorts/Gq3N2itAltY?si=dX7g5MPBphCJuvf0
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Gq3N2itAltY?si=dX7g5MPBphCJuvf0
# Downloading video from URL: https://youtube.com/shorts/HSHBhLvKJPA?si=nFxSLw8-gtNjI7MU
# Video downloaded successfully!
# Video HSHBhLvKJPA_20240610064432.mp4 uploaded successfully!
# Video HSHBhLvKJPA_20240610064432.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/3AWwrIDasJ0?si=c6wMjwRtUVhqYUmO
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/3AWwrIDasJ0?si=c6wMjwRtUVhqYUmO
# Downloading video from URL: https://youtube.com/shorts/haqEIXu0WmQ?si=H3u2wOiQvANgTU_H
# Video downloaded successfully!
# Video haqEIXu0WmQ_20240610064437.mp4 uploaded successfully!
# Video haqEIXu0WmQ_20240610064437.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/DjHTsp1CHnc?si=MP2zwDKdKSv4kmLW
# Video downloaded successfully!
# Video DjHTsp1CHnc_20240610064446.mp4 uploaded successfully!
# Video DjHTsp1CHnc_20240610064446.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/KlYPFQ6nO-A?si=Lv776c92W5O7UOTh
# Video downloaded successfully!
# Video KlYPFQ6nO-A_20240610064455.mp4 uploaded successfully!
# Video KlYPFQ6nO-A_20240610064455.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Sx9coFYmrEg?si=j5bTBi-pknZJP2l5
# Video downloaded successfully!
# Video Sx9coFYmrEg_20240610064459.mp4 uploaded successfully!
# Video Sx9coFYmrEg_20240610064459.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/a9Z_JQkXpmI?si=0qNljM6OzZLr2ZQT
# Error downloading video from URL https://youtube.com/shorts/a9Z_JQkXpmI?si=0qNljM6OzZLr2ZQT: a9Z_JQkXpmI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/a9Z_JQkXpmI?si=0qNljM6OzZLr2ZQT
# Downloading video from URL: https://youtube.com/shorts/GD2bgFd9zqo?si=QhWTQp4gToOKVgNU
# Error downloading video from URL https://youtube.com/shorts/GD2bgFd9zqo?si=QhWTQp4gToOKVgNU: GD2bgFd9zqo is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/GD2bgFd9zqo?si=QhWTQp4gToOKVgNU
# Downloading video from URL: https://youtube.com/shorts/gpRaOMDhtAs?si=XkNDm78X-pFKnINY
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/gpRaOMDhtAs?si=XkNDm78X-pFKnINY
# Downloading video from URL: https://youtube.com/shorts/3EhLikVQjSU?si=ZvpsUAMDfAirA7zn
# Video downloaded successfully!
# Video 3EhLikVQjSU_20240610064513.mp4 uploaded successfully!
# Video 3EhLikVQjSU_20240610064513.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/mOgJTFkkaBg?si=vWXRP37-xzUQk4hV
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/mOgJTFkkaBg?si=vWXRP37-xzUQk4hV
# Downloading video from URL: https://youtube.com/shorts/vpWGU1wqtNY?si=qFrm_5LirpG6Ddf4
# Video downloaded successfully!
# Video vpWGU1wqtNY_20240610064522.mp4 uploaded successfully!
# Video vpWGU1wqtNY_20240610064522.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/pdEo0JPATp8?si=OaTLpbd0Nm0-pAXg
# Video downloaded successfully!
# Video pdEo0JPATp8_20240610064531.mp4 uploaded successfully!
# Video pdEo0JPATp8_20240610064531.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/GoL8FeMG0w8?si=fAxo7PAqHhSoTp2W
# Video downloaded successfully!
# Video GoL8FeMG0w8_20240610064537.mp4 uploaded successfully!
# Video GoL8FeMG0w8_20240610064537.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/HoRJP8LXBS8?si=pfUb9pYP-pWeMU2Q
# Video downloaded successfully!
# Video HoRJP8LXBS8_20240610064542.mp4 uploaded successfully!
# Video HoRJP8LXBS8_20240610064542.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/zFD-UZwq6H8?si=YULKbne4hjfwJdf7
# Video downloaded successfully!
# Video zFD-UZwq6H8_20240610064548.mp4 uploaded successfully!
# Video zFD-UZwq6H8_20240610064548.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QhH07vCV4Ao?si=3LrzSaflEN3uxxfo
# Video downloaded successfully!
# Video QhH07vCV4Ao_20240610064554.mp4 uploaded successfully!
# Video QhH07vCV4Ao_20240610064554.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/yGUegSsLc2k?si=ZPvW4kDKVfjeQxAT
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/yGUegSsLc2k?si=ZPvW4kDKVfjeQxAT
# Downloading video from URL: https://youtube.com/shorts/OdFA_jQ6R4U?si=6Bx4NsAKUoiRlr9o
# Error downloading video from URL https://youtube.com/shorts/OdFA_jQ6R4U?si=6Bx4NsAKUoiRlr9o: OdFA_jQ6R4U is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/OdFA_jQ6R4U?si=6Bx4NsAKUoiRlr9o
# Downloading video from URL: https://youtube.com/shorts/_L32dOXh688?si=Xyo2nQqYdD2eQjF7
# Error downloading video from URL https://youtube.com/shorts/_L32dOXh688?si=Xyo2nQqYdD2eQjF7: _L32dOXh688 is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/_L32dOXh688?si=Xyo2nQqYdD2eQjF7
# Downloading video from URL: https://youtube.com/shorts/cCcgaa_yo9M?si=yLxvz-U4K792nfbu
# Video downloaded successfully!
# Video cCcgaa_yo9M_20240610064604.mp4 uploaded successfully!
# Video cCcgaa_yo9M_20240610064604.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/vWB_yQitqP0?si=coeU888yimIJfgUP
# Video downloaded successfully!
# Video vWB_yQitqP0_20240610064610.mp4 uploaded successfully!
# Video vWB_yQitqP0_20240610064610.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QeWQkFOXTVo?si=xseEHiH44508oVgm
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/QeWQkFOXTVo?si=xseEHiH44508oVgm
# Downloading video from URL: https://youtube.com/shorts/-l2xYPI1RD0?si=DC5mbn1fwPgtOMvB
# Video downloaded successfully!
# Video -l2xYPI1RD0_20240610064619.mp4 uploaded successfully!
# Video -l2xYPI1RD0_20240610064619.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Aloe-9FmkIo?si=FU9mz0A_eCPlXMHT
# Video downloaded successfully!
# Video Aloe-9FmkIo_20240610064623.mp4 uploaded successfully!
# Video Aloe-9FmkIo_20240610064623.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/GsV2bi6XBoU?si=S00vW0ZkTNVIMmCU
# Video downloaded successfully!
# Video GsV2bi6XBoU_20240610064629.mp4 uploaded successfully!
# Video GsV2bi6XBoU_20240610064629.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/VxoAnPR850g?si=IoZN__36JfZWU6tg
# Error downloading video from URL https://youtube.com/shorts/VxoAnPR850g?si=IoZN__36JfZWU6tg: VxoAnPR850g is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/VxoAnPR850g?si=IoZN__36JfZWU6tg
# Downloading video from URL: https://youtube.com/shorts/yXJVOEbzVeI?si=5cu7Ue1UynCkUGOB
# Error downloading video from URL https://youtube.com/shorts/yXJVOEbzVeI?si=5cu7Ue1UynCkUGOB: yXJVOEbzVeI is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/yXJVOEbzVeI?si=5cu7Ue1UynCkUGOB
# Downloading video from URL: https://youtube.com/shorts/w5kRvE91Qw4?si=qa84gsUtYMoj1HDf
# Video downloaded successfully!
# Video w5kRvE91Qw4_20240610064634.mp4 uploaded successfully!
# Video w5kRvE91Qw4_20240610064634.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/8WwK7a7iI9w?si=QBqwI_LCZt4mkb4q
# Video downloaded successfully!
# Video 8WwK7a7iI9w_20240610064640.mp4 uploaded successfully!
# Video 8WwK7a7iI9w_20240610064640.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/D5G8rgJkrlU?si=FMeCRWHHC7oTe9Ev
# Video downloaded successfully!
# Video D5G8rgJkrlU_20240610064655.mp4 uploaded successfully!
# Video D5G8rgJkrlU_20240610064655.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ztqa7HOazPU?si=wfH8r2h9R0N79Ktq
# Video downloaded successfully!
# Video ztqa7HOazPU_20240610064700.mp4 uploaded successfully!
# Video ztqa7HOazPU_20240610064700.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/TWK9jjOrD6U?si=vO69JGFlzLLkxsqk
# Video downloaded successfully!
# Video TWK9jjOrD6U_20240610064704.mp4 uploaded successfully!
# Video TWK9jjOrD6U_20240610064704.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0L51GUUOTPc?si=0x1RuOkzGmk8qqlU
# Error downloading video from URL https://youtube.com/shorts/0L51GUUOTPc?si=0x1RuOkzGmk8qqlU: 0L51GUUOTPc is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/0L51GUUOTPc?si=0x1RuOkzGmk8qqlU
# Downloading video from URL: https://youtube.com/shorts/kJl3PjgGW-c?si=LAlbS0DHgw9tHtcF
# Video downloaded successfully!
# Video kJl3PjgGW-c_20240610064715.mp4 uploaded successfully!
# Video kJl3PjgGW-c_20240610064715.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/S1EvYEr4GAc?si=5yYVUarml8Qep_Fd
# Video downloaded successfully!
# Video S1EvYEr4GAc_20240610064717.mp4 uploaded successfully!
# Video S1EvYEr4GAc_20240610064717.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/93BQdUg3aFM?si=bpgGKCOwfDr3p7iX
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/93BQdUg3aFM?si=bpgGKCOwfDr3p7iX
# Downloading video from URL: https://youtube.com/shorts/3DDq_xMR5vM?si=REzXuxCgzZU7K-nZ
# Error downloading video from URL https://youtube.com/shorts/3DDq_xMR5vM?si=REzXuxCgzZU7K-nZ: 3DDq_xMR5vM is unavailable
# Failed to download video from URL: https://youtube.com/shorts/3DDq_xMR5vM?si=REzXuxCgzZU7K-nZ
# Downloading video from URL: https://youtube.com/shorts/RFF8o9OZiCs?si=JjHzZL6BO4W-H27d
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/RFF8o9OZiCs?si=JjHzZL6BO4W-H27d
# Downloading video from URL: https://youtube.com/shorts/7Z2X2Zjm83Q?si=dwJM5wFoeVw2oLYu
# Video downloaded successfully!
# Video 7Z2X2Zjm83Q_20240610064728.mp4 uploaded successfully!
# Video 7Z2X2Zjm83Q_20240610064728.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ZKzd1OuUMq4?si=pnHzSMwGfU9S2hBr
# Error downloading video from URL https://youtube.com/shorts/ZKzd1OuUMq4?si=pnHzSMwGfU9S2hBr: ZKzd1OuUMq4 is unavailable
# Failed to download video from URL: https://youtube.com/shorts/ZKzd1OuUMq4?si=pnHzSMwGfU9S2hBr
# Downloading video from URL: https://youtube.com/shorts/ixuM8leNU5M?si=DYc-lsSzuDMK86w1
# Error downloading video from URL https://youtube.com/shorts/ixuM8leNU5M?si=DYc-lsSzuDMK86w1: ixuM8leNU5M is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/ixuM8leNU5M?si=DYc-lsSzuDMK86w1
# Downloading video from URL: https://youtube.com/shorts/8z5PQ3yasdQ?si=KgWsZAqsf8CJ-mYv
# Video downloaded successfully!
# Video 8z5PQ3yasdQ_20240610064733.mp4 uploaded successfully!
# Video 8z5PQ3yasdQ_20240610064733.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/iYaIC9K1X84?si=yuof_OU54JlcYA-O
# Video downloaded successfully!
# Video iYaIC9K1X84_20240610064742.mp4 uploaded successfully!
# Video iYaIC9K1X84_20240610064742.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/qzok18OdEMs?si=Cs_64C4-1-kX4bc3
# Error downloading video from URL https://youtube.com/shorts/qzok18OdEMs?si=Cs_64C4-1-kX4bc3: qzok18OdEMs is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/qzok18OdEMs?si=Cs_64C4-1-kX4bc3
# Downloading video from URL: https://youtube.com/shorts/Y4YcX1g4y84?si=FrWTG6fsybsR0_3n
# Video downloaded successfully!
# Video Y4YcX1g4y84_20240610064749.mp4 uploaded successfully!
# Video Y4YcX1g4y84_20240610064749.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/47Mh3G4sXCg?si=tprst3-57_YmtVlp
# Video downloaded successfully!
# Video 47Mh3G4sXCg_20240610064754.mp4 uploaded successfully!
# Video 47Mh3G4sXCg_20240610064754.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/0fVEMHaTs7g?si=YUO2AQ_Pfrueyvvp
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/0fVEMHaTs7g?si=YUO2AQ_Pfrueyvvp
# Downloading video from URL: https://youtube.com/shorts/mFmvcRtUJ_w?si=P2lECiqVqBOCrz8f
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/mFmvcRtUJ_w?si=P2lECiqVqBOCrz8f
# Downloading video from URL: https://youtube.com/shorts/bVlU04e3X28?si=y0PPBbr34bor8aIu
# Video downloaded successfully!
# Video bVlU04e3X28_20240610064810.mp4 uploaded successfully!
# Video bVlU04e3X28_20240610064810.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Ssg8kZZA0Y0?si=5cPMzgr7WV5REc4X
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/Ssg8kZZA0Y0?si=5cPMzgr7WV5REc4X
# Downloading video from URL: https://youtube.com/shorts/hUaUB3rZsAM?si=jzcqI4lVWjK7C2mB
# Error downloading video from URL https://youtube.com/shorts/hUaUB3rZsAM?si=jzcqI4lVWjK7C2mB: hUaUB3rZsAM is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/hUaUB3rZsAM?si=jzcqI4lVWjK7C2mB
# Downloading video from URL: https://youtube.com/shorts/xeLAL5i9Nc4?si=2dPOWTJ-lvQMAvuK
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/xeLAL5i9Nc4?si=2dPOWTJ-lvQMAvuK
# Downloading video from URL: https://youtube.com/shorts/wFx7Koop8hM?si=Xpdvh-3GKBAlhcX5
# Error downloading video from URL https://youtube.com/shorts/wFx7Koop8hM?si=Xpdvh-3GKBAlhcX5: 'streamingData'
# Failed to download video from URL: https://youtube.com/shorts/wFx7Koop8hM?si=Xpdvh-3GKBAlhcX5
# Downloading video from URL: https://youtube.com/shorts/ts1K876kWhE?si=yf5MHApdVYlREU1H
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ts1K876kWhE?si=yf5MHApdVYlREU1H
# Downloading video from URL: https://youtube.com/shorts/AjPJ_Qfhm5U?si=dj6t-olHX59YHtpS
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/AjPJ_Qfhm5U?si=dj6t-olHX59YHtpS
# Downloading video from URL: https://youtube.com/shorts/4GwhsC0oWIU?si=jSujNYPLI2CCQgL-
# Error downloading video from URL https://youtube.com/shorts/4GwhsC0oWIU?si=jSujNYPLI2CCQgL-: 4GwhsC0oWIU is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/4GwhsC0oWIU?si=jSujNYPLI2CCQgL-
# Downloading video from URL: https://youtube.com/shorts/1DAA-93ab0Y?si=8IkAbTQh_rZLFj2E
# Error downloading video from URL https://youtube.com/shorts/1DAA-93ab0Y?si=8IkAbTQh_rZLFj2E: 1DAA-93ab0Y is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/1DAA-93ab0Y?si=8IkAbTQh_rZLFj2E
# Downloading video from URL: https://youtube.com/shorts/7UDVy9x2keQ?si=u-YKiB9UI6Z2K6yZ
# Error downloading video from URL https://youtube.com/shorts/7UDVy9x2keQ?si=u-YKiB9UI6Z2K6yZ: 7UDVy9x2keQ is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/7UDVy9x2keQ?si=u-YKiB9UI6Z2K6yZ
# Downloading video from URL: https://youtube.com/shorts/3wz4HS_UkOI?si=vadkHyTdLPy1JxMg
# Video downloaded successfully!
# Video 3wz4HS_UkOI_20240610064835.mp4 uploaded successfully!
# Video 3wz4HS_UkOI_20240610064835.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ZE1p76j4Pio?si=yRypIFIf2Lj4D_YY
# Video downloaded successfully!
# Video ZE1p76j4Pio_20240610064838.mp4 uploaded successfully!
# Video ZE1p76j4Pio_20240610064838.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/SvFuhyCi_fg?si=xgt65YfQlR7qRGng
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/SvFuhyCi_fg?si=xgt65YfQlR7qRGng
# Downloading video from URL: https://youtube.com/shorts/cDVAaTXDsjs?si=vvHgi_s4fcegCqlO
# Video downloaded successfully!
# Video cDVAaTXDsjs_20240610064846.mp4 uploaded successfully!
# Video cDVAaTXDsjs_20240610064846.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/gajqh_bAQSY?si=wo_cTaKCrfVfPBg-
# Video downloaded successfully!
# Video gajqh_bAQSY_20240610064852.mp4 uploaded successfully!
# Video gajqh_bAQSY_20240610064852.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/_AZV0rP2tcw?si=vHBoVtgzX_rKUlfw
# Video downloaded successfully!
# Video _AZV0rP2tcw_20240610064858.mp4 uploaded successfully!
# Video _AZV0rP2tcw_20240610064858.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/iOI_gN314T0?si=FcPNixdDykwrFoAt
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/iOI_gN314T0?si=FcPNixdDykwrFoAt
# Downloading video from URL: https://youtube.com/shorts/uAOs208i5og?si=ZWaH23hEy4Q66GP9
# Video downloaded successfully!
# Video uAOs208i5og_20240610064912.mp4 uploaded successfully!
# Video uAOs208i5og_20240610064912.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/9FPdbMmK5o4?si=R2o4C7Hn1lOEsaKa
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/9FPdbMmK5o4?si=R2o4C7Hn1lOEsaKa
# Downloading video from URL: https://youtube.com/shorts/SekA57AxJVE?si=HOQzohNUATZ2qxTa
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/SekA57AxJVE?si=HOQzohNUATZ2qxTa
# Downloading video from URL: https://youtube.com/shorts/YL6QKcscJyc?si=8bRi68cTnuKLPdvG
# Video downloaded successfully!
# ...
# Video downloaded successfully!
# Video DEDg4NZaOIg_20240610081438.mp4 uploaded successfully!
# Video DEDg4NZaOIg_20240610081438.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/i5cIhdE0PqU?si=uNA1c2620qx00bT2
# Video downloaded successfully!
# Video i5cIhdE0PqU_20240610081445.mp4 uploaded successfully!
# Video i5cIhdE0PqU_20240610081445.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/do_1svI6Kkk?si=jZG5uB-J_OoXPYhI
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/do_1svI6Kkk?si=jZG5uB-J_OoXPYhI
# Downloading video from URL: https://youtube.com/shorts/nAdpNwH_jsw?si=0K13vbk1fTUt_XAP
# Video downloaded successfully!
# Video nAdpNwH_jsw_20240610081453.mp4 uploaded successfully!
# Video nAdpNwH_jsw_20240610081453.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Qso9-gri_SU?si=fxtUlcqKbeYsrQu4
# Video downloaded successfully!
# Video Qso9-gri_SU_20240610081455.mp4 uploaded successfully!
# Video Qso9-gri_SU_20240610081455.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/hxQr0zt-Wco?si=wBEgB_5wjuwAUrrR
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/hxQr0zt-Wco?si=wBEgB_5wjuwAUrrR
# Downloading video from URL: https://youtube.com/shorts/G281hsD9z8M?si=QIbRIM-iLdrI-g2O
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/G281hsD9z8M?si=QIbRIM-iLdrI-g2O
# Downloading video from URL: https://youtube.com/shorts/UyZBCYja_yQ?si=Juvk2VblOKxv4-Gs
# Video downloaded successfully!
# Video UyZBCYja_yQ_20240610081509.mp4 uploaded successfully!
# Video UyZBCYja_yQ_20240610081509.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/HMahI-QdSHs?si=kpa6FQRtzmst4S_U
# Video downloaded successfully!
# Video HMahI-QdSHs_20240610081513.mp4 uploaded successfully!
# Video HMahI-QdSHs_20240610081513.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/kmWju4rxUBM?si=hAdnkAprZL-OLrZd
# Video downloaded successfully!
# Video kmWju4rxUBM_20240610081516.mp4 uploaded successfully!
# Video kmWju4rxUBM_20240610081516.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/uuYiTHY9PIg?si=-hOOYVLx4AeAbgKN
# Video downloaded successfully!
# Video uuYiTHY9PIg_20240610081519.mp4 uploaded successfully!
# Video uuYiTHY9PIg_20240610081519.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/OtQ1p0LTxpQ?si=IMgdyu2L2Qt1AkIN
# Video downloaded successfully!
# Video OtQ1p0LTxpQ_20240610081522.mp4 uploaded successfully!
# Video OtQ1p0LTxpQ_20240610081522.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/Mg9IUWM8vzM?si=-FSamWs25PO0aZs9
# Video downloaded successfully!
# Video Mg9IUWM8vzM_20240610081525.mp4 uploaded successfully!
# Video Mg9IUWM8vzM_20240610081525.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QPCduv_2vhU?si=8reWAEA4ax-cJHk5
# Video downloaded successfully!
# Video QPCduv_2vhU_20240610081530.mp4 uploaded successfully!
# Video QPCduv_2vhU_20240610081530.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/t_ZXbPuYu7w?si=9cyJh9GFsJWOPqm8
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/t_ZXbPuYu7w?si=9cyJh9GFsJWOPqm8
# Downloading video from URL: https://youtube.com/shorts/xas--ICqYcI?si=CAcFbmoy3DJtwujk
# Video downloaded successfully!
# Video xas--ICqYcI_20240610081538.mp4 uploaded successfully!
# Video xas--ICqYcI_20240610081538.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/4ihK0Sqs_XM?si=-3OY8wRX6we8CBWJ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/4ihK0Sqs_XM?si=-3OY8wRX6we8CBWJ
# Downloading video from URL: https://youtube.com/shorts/BgX-pcQKXtI?si=1TNQzJnULsHchUPj
# Video downloaded successfully!
# Video BgX-pcQKXtI_20240610081545.mp4 uploaded successfully!
# Video BgX-pcQKXtI_20240610081545.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/MZY3PTimlWs?si=YwD4w9nkst_ln9rv
# Video downloaded successfully!
# Video MZY3PTimlWs_20240610081548.mp4 uploaded successfully!
# Video MZY3PTimlWs_20240610081548.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/7pUsi_REehU?si=lGbjvzgp9fVrlWJR
# Error downloading video from URL https://youtube.com/shorts/7pUsi_REehU?si=lGbjvzgp9fVrlWJR: 7pUsi_REehU is unavailable
# Failed to download video from URL: https://youtube.com/shorts/7pUsi_REehU?si=lGbjvzgp9fVrlWJR
# Downloading video from URL: https://youtube.com/shorts/4Yq_R6FLIXE?si=Dy-MZwJSlxEZziKa
# Video downloaded successfully!
# Video 4Yq_R6FLIXE_20240610081550.mp4 uploaded successfully!
# Video 4Yq_R6FLIXE_20240610081550.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/R8j4E-9cFKw?si=xBNMz89vMpwrF1Pb
# Video downloaded successfully!
# Video R8j4E-9cFKw_20240610081553.mp4 uploaded successfully!
# Video R8j4E-9cFKw_20240610081553.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/HjEPJVLOCyk?si=XSjpk2z3HPHQ-nim
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/HjEPJVLOCyk?si=XSjpk2z3HPHQ-nim
# Downloading video from URL: https://youtube.com/shorts/DEYkel48W_Q?si=tfZGhQlHc80RYt4V
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/DEYkel48W_Q?si=tfZGhQlHc80RYt4V
# Downloading video from URL: https://youtube.com/shorts/8T5ZlhrdFIk?si=gHhCXF2TEZUo-v_9
# Video downloaded successfully!
# Video 8T5ZlhrdFIk_20240610081600.mp4 uploaded successfully!
# Video 8T5ZlhrdFIk_20240610081600.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/3DUTP4ohpqs?si=49GY-jwsg_fhJHH_
# Video downloaded successfully!
# Video 3DUTP4ohpqs_20240610081605.mp4 uploaded successfully!
# Video 3DUTP4ohpqs_20240610081605.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/dsH5kCSwAO0?si=1HwB62rfBrq0EmyC
# Video downloaded successfully!
# Video dsH5kCSwAO0_20240610081612.mp4 uploaded successfully!
# Video dsH5kCSwAO0_20240610081612.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/psnl1KdXJgw?si=xgAGHxAtRhsQNU7p
# Video downloaded successfully!
# Video psnl1KdXJgw_20240610081615.mp4 uploaded successfully!
# Video psnl1KdXJgw_20240610081615.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/73YqBBmxs7E?si=1gAAtSaArk0-10dj
# Video downloaded successfully!
# Video 73YqBBmxs7E_20240610081618.mp4 uploaded successfully!
# Video 73YqBBmxs7E_20240610081618.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/zd05i_5pCJM?si=2DrdTekghhfLpwa4
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/zd05i_5pCJM?si=2DrdTekghhfLpwa4
# Downloading video from URL: https://youtube.com/shorts/Udt4GTEMgMo?si=dAVk0qtG_g_GoCW4
# Video downloaded successfully!
# Video Udt4GTEMgMo_20240610081627.mp4 uploaded successfully!
# Video Udt4GTEMgMo_20240610081627.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/X5cHH6CgB84?si=cX1DuKHSL-UE4sXe
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/X5cHH6CgB84?si=cX1DuKHSL-UE4sXe
# Downloading video from URL: https://youtube.com/shorts/SrzexivKt1I?si=CLgo6e1kahYbDvO8
# Video downloaded successfully!
# Video SrzexivKt1I_20240610081636.mp4 uploaded successfully!
# Video SrzexivKt1I_20240610081636.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/-mIQPQyrvd8?si=0DoklGSmdm6cg6fL
# Video downloaded successfully!
# Video -mIQPQyrvd8_20240610081639.mp4 uploaded successfully!
# Video -mIQPQyrvd8_20240610081639.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/vydAPvVyWco?si=-naSiP91MomPjxET
# Video downloaded successfully!
# Video vydAPvVyWco_20240610081641.mp4 uploaded successfully!
# Video vydAPvVyWco_20240610081641.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/6wx0wKKTGks?si=kIsnsTvXW54wGD6t
# Video downloaded successfully!
# Video 6wx0wKKTGks_20240610081643.mp4 uploaded successfully!
# Video 6wx0wKKTGks_20240610081643.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/J0fKmW_Ap0o?si=nWjB52NqJj1VPwLK
# Video downloaded successfully!
# Video J0fKmW_Ap0o_20240610081646.mp4 uploaded successfully!
# Video J0fKmW_Ap0o_20240610081646.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/37TXsz488kI?si=YnSkbOL8sHngYSUt
# Video downloaded successfully!
# Video 37TXsz488kI_20240610081648.mp4 uploaded successfully!
# Video 37TXsz488kI_20240610081648.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/yI9FI5GLaEw?si=TpWFTEhyemOB7TDb
# Video downloaded successfully!
# Video yI9FI5GLaEw_20240610081650.mp4 uploaded successfully!
# Video yI9FI5GLaEw_20240610081650.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/6LzOz7myD1s?si=vRs3H1AKCDsXYqhf
# Video downloaded successfully!
# Video 6LzOz7myD1s_20240610081653.mp4 uploaded successfully!
# Video 6LzOz7myD1s_20240610081653.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/nznGkm_TIqo?si=CfZZ7IgSVA4k9uUU
# Error downloading video from URL https://youtube.com/shorts/nznGkm_TIqo?si=CfZZ7IgSVA4k9uUU: nznGkm_TIqo is unavailable
# Failed to download video from URL: https://youtube.com/shorts/nznGkm_TIqo?si=CfZZ7IgSVA4k9uUU
# Downloading video from URL: https://youtube.com/shorts/RwzJl1oOA-o?si=eNDGTZskTWNwpocy
# Video downloaded successfully!
# Video RwzJl1oOA-o_20240610081656.mp4 uploaded successfully!
# Video RwzJl1oOA-o_20240610081656.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/OBHPbMVAMLo?si=_DizNBobAilpqgV2
# Video downloaded successfully!
# Video OBHPbMVAMLo_20240610081702.mp4 uploaded successfully!
# Video OBHPbMVAMLo_20240610081702.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/ocA_iKvTto4?si=12W_TNjEFpa411rv
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/ocA_iKvTto4?si=12W_TNjEFpa411rv
# Downloading video from URL: https://youtube.com/shorts/Knqc_ZVrEFE?si=5ku6fEwI2J2P4a3c
# Video downloaded successfully!
# Video Knqc_ZVrEFE_20240610081711.mp4 uploaded successfully!
# Video Knqc_ZVrEFE_20240610081711.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/U-B6i56FsWg?si=XtvV0s54fVQKysqR
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/U-B6i56FsWg?si=XtvV0s54fVQKysqR
# Downloading video from URL: https://youtube.com/shorts/DwwT9xMgBr4?si=EBKesNg24Emu6XAh
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/DwwT9xMgBr4?si=EBKesNg24Emu6XAh
# Downloading video from URL: https://youtube.com/shorts/_T8VqMn7H2g?si=HA9SEkWXWwy1pVTy
# Video downloaded successfully!
# Video _T8VqMn7H2g_20240610081719.mp4 uploaded successfully!
# Video _T8VqMn7H2g_20240610081719.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/w3YwdliBcj4?si=hDpCcoG3xljVLx1m
# Video downloaded successfully!
# Video w3YwdliBcj4_20240610081722.mp4 uploaded successfully!
# Video w3YwdliBcj4_20240610081722.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QCdS8v_A-rY?si=OVnp0ru_yqhcZ8_4
# Video downloaded successfully!
# Video QCdS8v_A-rY_20240610081724.mp4 uploaded successfully!
# Video QCdS8v_A-rY_20240610081724.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/LEEQMsKpKlA?si=PHAr139WnJjEqlPd
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/LEEQMsKpKlA?si=PHAr139WnJjEqlPd
# Downloading video from URL: https://youtube.com/shorts/zx7IVLEREgQ?si=Yrz4fB28wOa86UF1
# Video downloaded successfully!
# Video zx7IVLEREgQ_20240610081731.mp4 uploaded successfully!
# Video zx7IVLEREgQ_20240610081731.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/O3jToB6nXb4?si=yyfdLlJ04zDO4Ftg
# Video downloaded successfully!
# Video O3jToB6nXb4_20240610081733.mp4 uploaded successfully!
# Video O3jToB6nXb4_20240610081733.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/PjS3Zw2t2Vo?si=epgAQvOzLllVYRO_
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/PjS3Zw2t2Vo?si=epgAQvOzLllVYRO_
# Downloading video from URL: https://youtube.com/shorts/3G81S-Vyaww?si=nnXfbWcKAUPyufF7
# Video downloaded successfully!
# Video 3G81S-Vyaww_20240610081744.mp4 uploaded successfully!
# Video 3G81S-Vyaww_20240610081744.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/06oR51gQg98?si=YjmjaBGb9mRqUgXp
# Video downloaded successfully!
# Video 06oR51gQg98_20240610081749.mp4 uploaded successfully!
# Video 06oR51gQg98_20240610081749.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/QcgFeCKmf34?si=jq9I5TlHTKwZ3aTZ
# Video downloaded successfully!
# Video QcgFeCKmf34_20240610081753.mp4 uploaded successfully!
# Video QcgFeCKmf34_20240610081753.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/YX4BDmKZqBc?si=qQS319a8rJJL1dF2
# Video downloaded successfully!
# Video YX4BDmKZqBc_20240610081758.mp4 uploaded successfully!
# Video YX4BDmKZqBc_20240610081758.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/864vAvOndWc?si=Y9CScN_RYOBd1Rr0
# Video downloaded successfully!
# Video 864vAvOndWc_20240610081804.mp4 uploaded successfully!
# Video 864vAvOndWc_20240610081804.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/_oUhTfKKE1s?si=0YstTHyHV4qg9Hhe
# Video downloaded successfully!
# Video _oUhTfKKE1s_20240610081806.mp4 uploaded successfully!
# Video _oUhTfKKE1s_20240610081806.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/8TMGgQGFdhU?si=1wHI2djeQVEzfwi9
# Error downloading video from URL https://youtube.com/shorts/8TMGgQGFdhU?si=1wHI2djeQVEzfwi9: 8TMGgQGFdhU is age restricted, and can't be accessed without logging in.
# Failed to download video from URL: https://youtube.com/shorts/8TMGgQGFdhU?si=1wHI2djeQVEzfwi9
# Downloading video from URL: https://youtube.com/shorts/hBrang2ZbZs?si=zz1bTyw5J9MBZzYj
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/hBrang2ZbZs?si=zz1bTyw5J9MBZzYj
# Downloading video from URL: https://youtube.com/shorts/_SzFyFrvctA?si=U4mMf30ziqxhsLcQ
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/_SzFyFrvctA?si=U4mMf30ziqxhsLcQ
# Downloading video from URL: https://youtube.com/shorts/SQoSmIBB4-4?si=NcAZJnJkRu-T9yTv
# Video downloaded successfully!
# Video SQoSmIBB4-4_20240610081817.mp4 uploaded successfully!
# Video SQoSmIBB4-4_20240610081817.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/tGMnjA2u1K0?si=usmNoSHF5x9wDCTC
# Video downloaded successfully!
# Video tGMnjA2u1K0_20240610081824.mp4 uploaded successfully!
# Video tGMnjA2u1K0_20240610081824.mp4 uploaded successfully!
# Downloading video from URL: https://youtube.com/shorts/CbHk-LsYb7Q?si=OsDa6m3gkR2YR-8o
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/CbHk-LsYb7Q?si=OsDa6m3gkR2YR-8o
# Downloading video from URL: https://youtube.com/shorts/v1HFC1lKbA4?si=2nTgJOctcZDrCkEC
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/v1HFC1lKbA4?si=2nTgJOctcZDrCkEC
# Downloading video from URL: https://youtube.com/shorts/9G9ck1oRhx4?si=_zYbVuVfRv38gIc_
# Video downloaded successfully!
# Failed to download video from URL: https://youtube.com/shorts/9G9ck1oRhx4?si=_zYbVuVfRv38gIc_
# Downloading video from URL: https://youtube.com/shorts/gsggbonDu1g?si=PzDSZvkpy9e784V_

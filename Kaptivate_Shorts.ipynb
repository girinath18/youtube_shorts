# %% [markdown]
# <a href="https://colab.research.google.com/github/girinath18/youtube_shorts/blob/shorts_uploaded/Kaptivate_Shorts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pytube
# !pip install yt-dlp
# Out:
# Requirement already satisfied: pytube in /usr/local/lib/python3.10/dist-packages (15.0.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.7.25)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.7.4)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.20.0)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.0.7)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.7)

# %%
import os
import re
import yt_dlp
import pandas as pd
import requests
import json
from datetime import datetime
import cv2
import logging

# Setup logging
logging.basicConfig(filename='video_downloader.log', level=logging.DEBUG,
                    format='%(asctime)s %(levelname)s:%(message)s')

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def is_video_playable(file_path):
    """
    Check if the video file is playable using OpenCV.
    """
    try:
        cap = cv2.VideoCapture(file_path)
        if not cap.isOpened():
            return False
        ret, frame = cap.read()
        cap.release()
        return ret
    except Exception as e:
        logging.error(f"Error checking video playability: {e}")
        return False

def download_youtube_shorts(url, output_folder):
    retries = 3
    for attempt in range(retries):
        try:
            ydl_opts = {
                'format': 'best',
                'outtmpl': os.path.join(output_folder, '%(id)s.%(ext)s')
            }
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                info_dict = ydl.extract_info(url, download=True)
                video_id = info_dict.get("id", "")
                title = clean_text(info_dict.get('title', ''))
                description = clean_text(info_dict.get('description', ''))
                filename = f"{video_id}.mp4"
                filepath = os.path.join(output_folder, filename)

                # Save metadata to a text file
                metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
                with open(metadata_file, "w") as f:
                    f.write(f"Title: {title}\n")
                    f.write(f"Description: {description}\n")
                    f.write(f"Video ID: {video_id}\n")

                logging.info("Video downloaded successfully!")
                return title, description, video_id, filename, filepath
        except Exception as e:
            logging.error(f"Error downloading video from URL {url}: {e}")
            if attempt < retries - 1:
                logging.info(f"Retrying... ({attempt + 1}/{retries})")
            else:
                logging.error(f"Failed to download video after {retries} attempts.")
                return None, None, None, None, None

def upload_video(file_name, file_path):
    try:
        # Read the binary data from the video file
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        # Headers with your access key
        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'  # Specify content type as binary
        }

        # Make a PUT request to the API endpoint with binary data in the request body
        response = requests.put(url + file_name, headers=headers, data=binary_data)

        # Check if the request was successful (status code 201)
        if response.status_code == 201:
            logging.info(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            logging.error(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        # Define headers with your access key
        headers = {
            'Content-Type': 'application/json',  # Specify content type as JSON
        }

        # Define the JSON payload
        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,  # Using file_name directly
            "views": 0  # Views can be updated later
        }

        # Make a POST request to the API endpoint with binary data in the request body
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            logging.info(f"Post for video {file_name} created successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            logging.error(f"Error creating post for video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error creating post for video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    # Read input file into a list of lines
    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        # Split each line by comma to get URL, Category, Subcategory
        parts = line.strip().split(',')
        # Take the first three fields, even if there are more
        if len(parts) < 3:
            logging.error(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)

        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        logging.info(f"Downloading video from URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        # Check if the download was successful
        if title and description and video_id and file_name and file_path:
            # Check if the video is playable
            if is_video_playable(file_path):
                # Call the function to upload the video
                if upload_video(file_name, file_path) and create_post(title, description, category, subcategory, file_name):
                    success_count += 1
                else:
                    failure_count += 1
            else:
                logging.error(f"Video {file_name} is not playable and will not be uploaded.")
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            logging.error(f"Failed to download video from URL: {url}")
            failure_count += 1

    # Convert the extracted data to a DataFrame
    extracted_df = pd.DataFrame(extracted_data)
    extracted_df.to_csv('extracted_data.csv', index=False)
    logging.info("Extracted data saved successfully.")

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    logging.info("Upload report saved successfully.")

if __name__ == "__main__":
    main()

# %%
import os
import re
import yt_dlp
import pandas as pd
import requests
import json
from datetime import datetime
import cv2
import logging

# Setup logging
logging.basicConfig(filename='video_downloader.log', level=logging.DEBUG,
                    format='%(asctime)s %(levelname)s:%(message)s')

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def is_video_playable(file_path):
    """
    Check if the video file is playable using OpenCV.
    """
    try:
        cap = cv2.VideoCapture(file_path)
        if not cap.isOpened():
            return False
        ret, frame = cap.read()
        cap.release()
        return ret
    except Exception as e:
        logging.error(f"Error checking video playability: {e}")
        return False

def download_youtube_shorts(url, output_folder):
    retries = 3
    for attempt in range(retries):
        try:
            ydl_opts = {
                'format': 'best',
                'outtmpl': os.path.join(output_folder, '%(id)s.%(ext)s')
            }
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                info_dict = ydl.extract_info(url, download=True)
                video_id = info_dict.get("id", "")
                title = clean_text(info_dict.get('title', ''))
                description = clean_text(info_dict.get('description', ''))
                filename = f"{video_id}.mp4"
                filepath = os.path.join(output_folder, filename)

                # Save metadata to a text file
                metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
                with open(metadata_file, "w") as f:
                    f.write(f"Title: {title}\n")
                    f.write(f"Description: {description}\n")
                    f.write(f"Video ID: {video_id}\n")

                logging.info("Video downloaded successfully!")
                return title, description, video_id, filename, filepath
        except Exception as e:
            logging.error(f"Error downloading video from URL {url}: {e}")
            if attempt < retries - 1:
                logging.info(f"Retrying... ({attempt + 1}/{retries})")
            else:
                logging.error(f"Failed to download video after {retries} attempts.")
                return None, None, None, None, None

def upload_video(file_name, file_path):
    try:
        # Read the binary data from the video file
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        # Headers with your access key
        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'  # Specify content type as binary
        }

        # Make a PUT request to the API endpoint with binary data in the request body
        response = requests.put(url + file_name, headers=headers, data=binary_data)

        # Check if the request was successful (status code 201)
        if response.status_code == 201:
            logging.info(f"Video {file_name} uploaded successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            logging.error(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        # Define headers with your access key
        headers = {
            'Content-Type': 'application/json',  # Specify content type as JSON
        }

        # Define the JSON payload
        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,  # Using file_name directly
            "views": 0  # Views can be updated later
        }

        # Make a POST request to the API endpoint with binary data in the request body
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            logging.info(f"Post for video {file_name} created successfully!")
            return True
        else:
            # If the request was not successful, print the error status code
            logging.error(f"Error creating post for video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error creating post for video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    # Read input file into a list of lines
    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        # Split each line by comma to get URL, Category, Subcategory
        parts = line.strip().split(',')
        # Take the first three fields, even if there are more
        if len(parts) < 3:
            logging.error(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)

        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        logging.info(f"Downloading video from URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        # Check if the download was successful
        if title and description and video_id and file_name and file_path:
            # Check if the video is playable
            if is_video_playable(file_path):
                # Call the function to upload the video
                if upload_video(file_name, file_path):
                    if create_post(title, description, category, subcategory, file_name):
                        success_count += 1
                    else:
                        failure_count += 1
                else:
                    failure_count += 1
            else:
                logging.error(f"Video {file_name} is not playable and will not be uploaded.")
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            logging.error(f"Failed to download video from URL: {url}")
            failure_count += 1

    # Convert the extracted data to a DataFrame
    extracted_df = pd.DataFrame(extracted_data)
    extracted_df.to_csv('extracted_data.csv', index=False)
    logging.info("Extracted data saved successfully.")

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    logging.info("Upload report saved successfully.")

if __name__ == "__main__":
    main()

# %%
import os
import re
import yt_dlp
import pandas as pd
import requests
import json
from datetime import datetime
import cv2
import logging

# Setup logging
logging.basicConfig(filename='video_downloader.log', level=logging.DEBUG,
                    format='%(asctime)s %(levelname)s:%(message)s')

def clean_text(text):
    # Remove special characters and emojis using re
    cleaned_text = re.sub(r'[^\w\s\.]', '', text)
    return cleaned_text

def is_video_playable(file_path):
    """
    Check if the video file is playable using OpenCV.
    """
    try:
        cap = cv2.VideoCapture(file_path)
        if not cap.isOpened():
            return False
        ret, frame = cap.read()
        cap.release()
        return ret
    except Exception as e:
        logging.error(f"Error checking video playability: {e}")
        return False

def download_youtube_shorts(url, output_folder):
    retries = 3
    for attempt in range(retries):
        try:
            ydl_opts = {
                'format': 'best',
                'outtmpl': os.path.join(output_folder, '%(id)s.%(ext)s')
            }
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                info_dict = ydl.extract_info(url, download=True)
                video_id = info_dict.get("id", "")
                title = clean_text(info_dict.get('title', ''))
                description = clean_text(info_dict.get('description', ''))
                filename = f"{video_id}.mp4"
                filepath = os.path.join(output_folder, filename)

                # Save metadata to a text file
                metadata_file = os.path.join(output_folder, f"{video_id}_metadata.txt")
                with open(metadata_file, "w") as f:
                    f.write(f"Title: {title}\n")
                    f.write(f"Description: {description}\n")
                    f.write(f"Video ID: {video_id}\n")

                logging.info(f"Video downloaded successfully: {filename}")
                return title, description, video_id, filename, filepath
        except Exception as e:
            logging.error(f"Error downloading video from URL {url}: {e}")
            if attempt < retries - 1:
                logging.info(f"Retrying download... ({attempt + 1}/{retries})")
            else:
                logging.error(f"Failed to download video after {retries} attempts.")
                return None, None, None, None, None

def upload_video(file_name, file_path):
    try:
        with open(file_path, 'rb') as file:
            binary_data = file.read()

        url = 'https://storage.bunnycdn.com/kaptivate/prod/'
        access_key = '7b8d3799-ffff-4d96-8d41f4e535a1-f88f-4104'

        headers = {
            'AccessKey': access_key,
            'Content-Type': 'application/octet-stream'
        }

        response = requests.put(url + file_name, headers=headers, data=binary_data)

        if response.status_code == 201:
            logging.info(f"Video uploaded successfully: {file_name}")
            return True
        else:
            logging.error(f"Error uploading video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error uploading video {file_name}: {e}")
        return False

def create_post(title, description, category, subcategory, file_name):
    try:
        url = 'https://lwbauabdrh.execute-api.ap-south-1.amazonaws.com/prod/create-post/'

        headers = {
            'Content-Type': 'application/json',
        }

        payload = {
            "title": title,
            "description": description,
            "category": category,
            "subCategory1": subcategory,
            "source": file_name,
            "views": 0
        }

        response = requests.post(url, headers=headers, data=json.dumps(payload))

        if response.status_code == 200:
            logging.info(f"Post for video {file_name} created successfully!")
            return True
        else:
            logging.error(f"Error creating post for video {file_name}: {response.status_code}")
            return False
    except Exception as e:
        logging.error(f"Error creating post for video {file_name}: {e}")
        return False

def main():
    input_file = input("Enter the path to the input text file: ")

    with open(input_file, 'r') as f:
        lines = f.readlines()

    extracted_data = []
    success_count = 0
    failure_count = 0

    for line in lines:
        parts = line.strip().split(',')
        if len(parts) < 3:
            logging.error(f"Skipping line due to incorrect format: {line}")
            failure_count += 1
            continue
        url, category, subcategory = parts[:3]

        output_folder = os.path.join(os.getcwd(), category, subcategory)
        os.makedirs(output_folder, exist_ok=True)

        logging.info(f"Processing URL: {url}")

        title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)

        if title and description and video_id and file_name and file_path:
            if is_video_playable(file_path):
                if upload_video(file_name, file_path) and create_post(title, description, category, subcategory, file_name):
                    success_count += 1
                else:
                    failure_count += 1
            else:
                logging.error(f"Video {file_name} is not playable and will not be uploaded.")
                failure_count += 1

            extracted_data.append({
                'URL': url,
                'Category': category,
                'Subcategory': subcategory,
                'Title': title,
                'Description': description,
                'Video ID': video_id
            })
        else:
            logging.error(f"Failed to download video from URL: {url}")
            failure_count += 1

    extracted_df = pd.DataFrame(extracted_data)
    extracted_df.to_csv('extracted_data.csv', index=False)
    logging.info("Extracted data saved successfully.")

    report_df = pd.DataFrame({
        'Success Count': [success_count],
        'Failure Count': [failure_count]
    })

    report_df.to_csv('upload_report.csv', index=False)
    logging.info("Upload report saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Enter the path to the input text file: /content/Kaptivate List 2.txt
# [youtube] Extracting URL: https://youtube.com/shorts/D9lpvUDoXLM?si=VCme4Ujky-WmMBsk
# [youtube] D9lpvUDoXLM: Downloading webpage
# [youtube] D9lpvUDoXLM: Downloading ios player API JSON
# [youtube] D9lpvUDoXLM: Downloading m3u8 information
# [info] D9lpvUDoXLM: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/D9lpvUDoXLM.mp4
# [download] 100% of    1.62MiB in 00:00:00 at 1.62MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/CsnPhKu66Y8?si=tJZzossR0DtBr-Sr
# [youtube] CsnPhKu66Y8: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] CsnPhKu66Y8: Downloading ios player API JSON
# [youtube] CsnPhKu66Y8: Downloading player 1f8742dc
# [youtube] CsnPhKu66Y8: Downloading web player API JSON
# [youtube] CsnPhKu66Y8: Downloading m3u8 information
# [info] CsnPhKu66Y8: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/CsnPhKu66Y8.mp4
# [download] 100% of    1.74MiB in 00:00:00 at 5.10MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/kDh-PZPqQRc?si=pgw_z3uNs_kRfc49
# [youtube] kDh-PZPqQRc: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] kDh-PZPqQRc: Downloading ios player API JSON
# [youtube] kDh-PZPqQRc: Downloading player 1f8742dc
# [youtube] kDh-PZPqQRc: Downloading web player API JSON
# [youtube] kDh-PZPqQRc: Downloading m3u8 information
# [info] kDh-PZPqQRc: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/kDh-PZPqQRc.mp4
# [download] 100% of    1.07MiB in 00:00:00 at 2.65MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/fmnSL7CiZnM?si=XoCKOiVUpyi7QmCi
# [youtube] fmnSL7CiZnM: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] fmnSL7CiZnM: Downloading ios player API JSON
# [youtube] fmnSL7CiZnM: Downloading player 1f8742dc
# [youtube] fmnSL7CiZnM: Downloading web player API JSON
# [youtube] fmnSL7CiZnM: Downloading m3u8 information
# [info] fmnSL7CiZnM: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/fmnSL7CiZnM.mp4
# [download] 100% of    2.23MiB in 00:00:00 at 3.21MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/3wCTDVksjNw?si=0EBCEnw2IwFWbygk
# [youtube] 3wCTDVksjNw: Downloading webpage
# [youtube] 3wCTDVksjNw: Downloading ios player API JSON
# [youtube] 3wCTDVksjNw: Downloading m3u8 information
# [info] 3wCTDVksjNw: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/3wCTDVksjNw.mp4
# [download] 100% of    1.57MiB in 00:00:01 at 1.33MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/LUUyR0qV-z4?si=LC41aZ0UlDSO7tUj
# [youtube] LUUyR0qV-z4: Downloading webpage
# [youtube] LUUyR0qV-z4: Downloading ios player API JSON
# [youtube] LUUyR0qV-z4: Downloading m3u8 information
# [info] LUUyR0qV-z4: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/LUUyR0qV-z4.mp4
# [download] 100% of    2.16MiB in 00:00:01 at 1.59MiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/m2X6Z8CCFFo?si=LjC3jfUFF4yFiVWZ
# [youtube] m2X6Z8CCFFo: Downloading webpage
# [youtube] m2X6Z8CCFFo: Downloading ios player API JSON
# [youtube] m2X6Z8CCFFo: Downloading m3u8 information
# [info] m2X6Z8CCFFo: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/m2X6Z8CCFFo.mp4
# [download] 100% of   92.86KiB in 00:00:01 at 82.34KiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# [youtube] C9a744zp200: Downloading webpage
# [youtube] C9a744zp200: Downloading ios player API JSON
# ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR: ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# [youtube] Extracting URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# [youtube] C9a744zp200: Downloading webpage
# [youtube] C9a744zp200: Downloading ios player API JSON
# ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR: ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# [youtube] Extracting URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# [youtube] C9a744zp200: Downloading webpage
# [youtube] C9a744zp200: Downloading ios player API JSON
# ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR: ERROR: [youtube] C9a744zp200: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Failed to download video after 3 attempts.
# ERROR:root:Failed to download video from URL: https://youtube.com/shorts/C9a744zp200?si=dCXjivKykqKW9NrR
# [youtube] Extracting URL: https://youtube.com/shorts/vE09jn3bd9I?si=5IgLb_YW0vhQk-di
# [youtube] vE09jn3bd9I: Downloading webpage
# [youtube] vE09jn3bd9I: Downloading ios player API JSON
# [youtube] vE09jn3bd9I: Downloading m3u8 information
# [info] vE09jn3bd9I: Downloading 1 format(s): 18
# [download] Destination: /content/tamil/love/vE09jn3bd9I.mp4
# [download] 100% of  848.74KiB in 00:00:00 at 2.10MiB/s
# ERROR:root:Failed to download video from URL: https://youtube.com/shorts/vE09jn3bd9I?si=5IgLb_YW0vhQk-di
# [youtube] Extracting URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# [youtube] hsyhqqqtTZ0: Downloading webpage
# [youtube] hsyhqqqtTZ0: Downloading ios player API JSON
# ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD: ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# [youtube] Extracting URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# [youtube] hsyhqqqtTZ0: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] hsyhqqqtTZ0: Downloading ios player API JSON
# [youtube] hsyhqqqtTZ0: Downloading player 1f8742dc
# [youtube] hsyhqqqtTZ0: Downloading web player API JSON
# ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD: ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# [youtube] Extracting URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# [youtube] hsyhqqqtTZ0: Downloading webpage
# [youtube] hsyhqqqtTZ0: Downloading ios player API JSON
# ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Error downloading video from URL https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD: ERROR: [youtube] hsyhqqqtTZ0: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR:root:Failed to download video after 3 attempts.
# ERROR:root:Failed to download video from URL: https://youtube.com/shorts/hsyhqqqtTZ0?si=_HvJCPnFF18oNIrD
# [youtube] Extracting URL: https://youtube.com/shorts/zL-tzTlTW7w?si=1MjvK08gx8XdCyMl
# [youtube] zL-tzTlTW7w: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] zL-tzTlTW7w: Downloading ios player API JSON
# [youtube] zL-tzTlTW7w: Downloading player 1f8742dc
# [youtube] zL-tzTlTW7w: Downloading web player API JSON
# [youtube] zL-tzTlTW7w: Downloading m3u8 information
# [info] zL-tzTlTW7w: Downloading 1 format(s): 18
# [download] Destination: /content/telugu/love/zL-tzTlTW7w.mp4
# [download] 100% of  498.47KiB in 00:00:00 at 1.82MiB/s
# ERROR:root:Failed to download video from URL: https://youtube.com/shorts/zL-tzTlTW7w?si=1MjvK08gx8XdCyMl
# [youtube] Extracting URL: https://youtube.com/shorts/SK6yi_n-Qgw?si=C5TahI0Ozn2dxJH1
# [youtube] SK6yi_n-Qgw: Downloading webpage
# [youtube] SK6yi_n-Qgw: Downloading ios player API JSON
# [youtube] SK6yi_n-Qgw: Downloading m3u8 information
# [info] SK6yi_n-Qgw: Downloading 1 format(s): 18
# [download] Destination: /content/telugu/love/SK6yi_n-Qgw.mp4
# [download] 100% of  285.94KiB in 00:00:00 at 387.79KiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/btyT2IigbYE?si=rXYANdWHdKMPN6v6
# [youtube] btyT2IigbYE: Downloading webpage
# [youtube] btyT2IigbYE: Downloading ios player API JSON
# [youtube] btyT2IigbYE: Downloading m3u8 information
# [info] btyT2IigbYE: Downloading 1 format(s): 18
# [download] Destination: /content/telugu/love/btyT2IigbYE.mp4
# [download] 100% of  267.17KiB in 00:00:00 at 370.02KiB/s
# [youtube] Extracting URL: https://youtube.com/shorts/0rGP0jOxs_I?si=RLvv87Mjsx-QpVTm
# [youtube] 0rGP0jOxs_I: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] 0rGP0jOxs_I: Downloading ios player API JSON
# [youtube] 0rGP0jOxs_I: Downloading player 1f8742dc
# [youtube] 0rGP0jOxs_I: Downloading web player API JSON
# [youtube] 0rGP0jOxs_I: Downloading m3u8 information
# [info] 0rGP0jOxs_I: Downloading 1 format(s): 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-745d39cb8eb3> in <cell line: 181>()
#     180
#     181 if __name__ == "__main__":
# --> 182     main()
#
# <ipython-input-5-745d39cb8eb3> in main()
#     143         logging.info(f"Processing URL: {url}")
#     144
# --> 145         title, description, video_id, file_name, file_path = download_youtube_shorts(url, output_folder)
#     146
#     147         if title and description and video_id and file_name and file_path:
#
# <ipython-input-5-745d39cb8eb3> in download_youtube_shorts(url, output_folder)
#      42             }
#      43             with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 44                 info_dict = ydl.extract_info(url, download=True)
#      45                 video_id = info_dict.get("id", "")
#      46                 title = clean_text(info_dict.get('title', ''))
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1613                     raise ExistingVideoReached
#    1614                 break
# -> 1615             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1616         else:
#    1617             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1624             while True:
#    1625                 try:
# -> 1626                     return func(self, *args, **kwargs)
#    1627                 except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1628                     raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1780         if process:
#    1781             self._wait_for_video(ie_result)
# -> 1782             return self.process_ie_result(ie_result, download, extra_info)
#    1783         else:
#    1784             return ie_result
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1839         if result_type == 'video':
#    1840             self.add_extra_info(ie_result, extra_info)
# -> 1841             ie_result = self.process_video_result(ie_result, download=download)
#    1842             self._raise_pending_errors(ie_result)
#    1843             additional_urls = (ie_result or {}).get('additional_urls')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_video_result(self, info_dict, download)
#    3013                 downloaded_formats.append(new_info)
#    3014                 try:
# -> 3015                     self.process_info(new_info)
#    3016                 except MaxDownloadsReached:
#    3017                     max_downloads_reached = True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     177     def wrapper(self, *args, **kwargs):
#     178         try:
# --> 179             return func(self, *args, **kwargs)
#     180         except _UnsafeExtensionError as error:
#     181             self.report_error(
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_info(self, info_dict)
#    3481                         # dl_filename == temp_filename could mean that the file was partially downloaded with --no-part.
#    3482                         # So we should try to resume the download
# -> 3483                         success, real_download = self.dl(temp_filename, info_dict)
#    3484                         info_dict['__real_download'] = real_download
#    3485                     else:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in dl(self, name, info, subtitle, test)
#    3201         if new_info.get('http_headers') is None:
#    3202             new_info['http_headers'] = self._calc_headers(new_info)
# -> 3203         return fd.download(name, new_info, subtitle)
#    3204
#    3205     def existing_file(self, filepaths, *, default_overwrite=True):
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/downloader/common.py in download(self, filename, info_dict, subtitle)
#     464             time.sleep(sleep_interval)
#     465
# --> 466         ret = self.real_download(filename, info_dict)
#     467         self._finish_multiline_status()
#     468         return ret, True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/downloader/http.py in real_download(self, filename, info_dict)
#     367         for retry in RetryManager(self.params.get('retries'), self.report_retry):
#     368             try:
# --> 369                 establish_connection()
#     370                 return download()
#     371             except RetryDownload as err:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/downloader/http.py in establish_connection()
#     118             # Establish connection
#     119             try:
# --> 120                 ctx.data = self.ydl.urlopen(request)
#     121                 # When trying to resume, Content-Range HTTP header of response has to be checked
#     122                 # to match the value of requested Range HTTP header. This is due to a webservers
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in urlopen(self, req)
#    4163
#    4164         try:
# -> 4165             return self._request_director.send(req)
#    4166         except NoSupportingHandlers as e:
#    4167             for ue in e.unsupported_errors:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/networking/common.py in send(self, request)
#     115             self._print_verbose(f'Sending request via "{handler.RH_NAME}"')
#     116             try:
# --> 117                 response = handler.send(request)
#     118             except RequestError:
#     119                 raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/networking/_helper.py in wrapper(self, *args, **kwargs)
#     206     def wrapper(self, *args, **kwargs):
#     207         try:
# --> 208             return func(self, *args, **kwargs)
#     209         except UnsupportedRequest as e:
#     210             if e.handler is None:
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/networking/common.py in send(self, request)
#     338         if not isinstance(request, Request):
#     339             raise TypeError('Expected an instance of Request')
# --> 340         return self._send(request)
#     341
#     342     @abc.abstractmethod
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/networking/_requests.py in _send(self, request)
#     326
#     327         try:
# --> 328             requests_res = session.request(
#     329                 method=request.method,
#     330                 url=request.url,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     722             # Redirect resolving generator.
#     723             gen = self.resolve_redirects(r, request, **kwargs)
# --> 724             history = [resp for resp in gen]
#     725         else:
#     726             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in <listcomp>(.0)
#     722             # Redirect resolving generator.
#     723             gen = self.resolve_redirects(r, request, **kwargs)
# --> 724             history = [resp for resp in gen]
#     725         else:
#     726             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263                 yield req
#     264             else:
# --> 265                 resp = self.send(
#     266                     req,
#     267                     stream=stream,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
